# %% [markdown]
# 69 ベクトル空間上の国名に関する単語ベクトルをt-SNEで可視化せよ

# %%
#69
from sklearn.manifold import TSNE

tsne = TSNE()
data = np.array([wv_from_bin[c] for c in countries])
embedded = tsne.fit_transform(data)
tsne.fit([wv_from_bin[c] for c in countries])
cmap = plt.get_cmap('Set1')
plt.figure(figsize=(15, 15), dpi=300)
plt.scatter(tsne.embedding_[:, 0], tsne.embedding_[:, 1])
for i, ((x, y), name) in enumerate(zip(tsne.embedding_, countries)):
    plt.annotate(name, (x, y), color=cmap(kmeans.labels_[i]))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-36096582d868> in <cell line: 6>()
#       4 tsne = TSNE()
#       5 data = np.array([wv_from_bin[c] for c in countries])
# ----> 6 tsne.fit([data[c] for c in countries])
#       7 cmap = plt.get_cmap('Set1')
#       8 plt.figure(figsize=(15, 15), dpi=300)
#
# <ipython-input-37-36096582d868> in <listcomp>(.0)
#       4 tsne = TSNE()
#       5 data = np.array([wv_from_bin[c] for c in countries])
# ----> 6 tsne.fit([data[c] for c in countries])
#       7 cmap = plt.get_cmap('Set1')
#       8 plt.figure(figsize=(15, 15), dpi=300)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
# TSNEモデルのインスタンス化
tsne = TSNE()

# リストをnumpy配列に変換してTSNEに渡す
data = np.array([wv_from_bin[c] for c in countries])

# TSNEモデルにデータをfit_transformで適合させて次元削減を行う
embedded = tsne.fit_transform(data)

# プロットの設定
plt.figure(figsize=(15, 15), dpi=300)
plt.scatter(embedded[:, 0], embedded[:, 1])

# アノテーションを追加
for i, (point, name) in enumerate(zip(embedded, countries)):
    plt.annotate(name, point)

plt.show()
