# %%
# !wget https://nlp100.github.io/data/jawiki-country.json.gz

# %%
#22 記事のカテゴリ名を（行単位ではなく名前で）抽出せよ．

# %%
import pandas as pd
import re
wiki = pd.read_json('jawiki-country.json.gz', lines = True)
uk = wiki[wiki['title']=='イギリス'].text.values
ls = uk[0].split('\n')
for line in ls:
    if re.search(pattern, line):
        line = line.replace('[[','').replace('Category:','').replace(']]','').replace('|*','').replace('|元','')
        print (line)
# Out:
# {{Sisterlinks|commons=United Kingdom|commonscat=United Kingdom|s=イギリス|n=イギリス|voy=United Kingdom}}
# イギリス
# イギリス連邦加盟国
# 英連邦王国
# G8加盟国
# 欧州連合加盟国
# 海洋国家
# 現存する君主国
# 島国
# 1801年に成立した国家・領域
