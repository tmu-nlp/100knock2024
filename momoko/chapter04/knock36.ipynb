# %%
from importnb import imports
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib
with imports("ipynb"):#これで"knock35.~~~"の形でknock35内で定義したものを再利用可能となった
    import knock35

neko_f_top10 = knock35.neko_frequency[0:10]
top10_num = []
top10_rabel = []
for atai in neko_f_top10:
    top10_rabel.append(atai[0])
    top10_num.append(atai[1])


plt.bar(top10_rabel,top10_num)
plt.xlabel("形態素")
plt.ylabel("出現頻度(回)")
plt.title("『吾輩は猫である』における形態素出現数top10")
plt.show()
