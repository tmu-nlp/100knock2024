# %%
from importnb import imports
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib
import collections

with imports("ipynb"):#これで"knock35.~~~"の形でknock35内で定義したものを再利用可能となった
    import knock35

data = collections.Counter(knock35.neko_words)
plt.hist(data.values(),range(1,50))#.values():値の一覧を取得できる．50は描画数
plt.xlabel("出現頻度")
plt.ylabel("単語の異なり数(種類数)")
plt.title("『吾輩は猫である』における，単語の出現頻度のヒストグラム")
plt.show()
