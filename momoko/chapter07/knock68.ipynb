# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from importnb import imports

with imports("ipynb"):
    from knock67 import *

# %%
"""
linkage
座標データのリストを入力すると，methodに基づいてデータ群が出力される
"""
linkage_calc = linkage(vec_num, method='ward')
dn = dendrogram(linkage_calc,labels=vec_country)#ラベルを国名に結びつける．x軸はデータラベル，y軸はユーグリット距離を示す．
plt.savefig("knock68.png")
