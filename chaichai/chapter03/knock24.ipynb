# %%
import json
import gzip
import re

def extract_media_files_uk(filename):
    """
    Wikipediaの記事ファイルから「イギリス」に関する記事本文中のメディアファイルをすべて抽出する

    Args:
        filename (str): 圧縮されたJSON形式のWikipedia記事ファイル

    Returns:
        list: 抽出されたメディアファイルのリスト
    """
    media_files = []

    with gzip.open(filename, 'rb') as f:
        for line in f:
            # JSON形式のデータをパースする
            data = json.loads(line.decode('utf-8'))

            # 記事名が「イギリス」に一致するかどうかを確認する
            if data['title'] != "イギリス":
                continue

            # 本文中のメディアファイルのURLを抽出する
            for match in re.finditer(r"\[\[(.*?)\]\]", data['text']):
                media_file = match.group(1)

                # ファイル名のみを抽出する
                if "|" in media_file:
                    media_file = media_file.split("|")[0]

                media_files.append(media_file.strip())

    return media_files

if __name__ == "__main__":
    # ファイルパスを指定する
    filename = "jawiki-country.json.gz"

    # 「イギリス」に関する記事本文中のメディアファイルを抽出する
    media_files = extract_media_files_uk(filename)

    # 抽出結果を表示する
    print(media_files)
# Out:
# ['スコットランド・ゲール語', 'ウェールズ語', 'アイルランド語', 'コーンウォール語', 'スコットランド語', 'ファイル:Royal Coat of Arms of the United Kingdom.svg', 'イギリスの国章', 'Dieu et mon droit', 'フランス語', 'Dieu et mon droit', '女王陛下万歳', 'ファイル:United States Navy Band - God Save the Queen.ogg', '英語', 'ロンドン', 'イギリスの君主', 'エリザベス2世', 'イギリスの首相', 'ボリス・ジョンソン', '貴族院 (イギリス)', ':en:Norman Fowler, Baron Fowler', '庶民院 (イギリス)', '連合王国最高裁判所', ':en:Brenda Hale, Baroness Hale of Richmond', 'イングランド王国', 'スコットランド王国', '合同法 (1707年)', 'グレートブリテン王国', 'グレートブリテン及びアイルランド連合王国', '合同法 (1800年)', 'スターリング・ポンド', '.uk', '.gb', 'ヨーロッパ大陸', 'グレートブリテン島', 'アイルランド島', '立憲君主制', '国家', 'ロンドン', '日本語', '通称', '#国名', 'イングランド', 'ウェールズ', 'スコットランド', '北アイルランド', 'イギリスのカントリー', '同君連合', '主権国家体制', '連邦', '国際連合安全保障理事会常任理事国', 'G7', 'G20', 'ビッグ4 (ヨーロッパ)', 'ウィーン体制', '1815年', '列強', '民主主義', '立憲君主制', '擬人化', 'ジョン・ブル', 'ブリタニア (女神)', '日本語', '直訳と意訳', '連合王国', '日本放送協会', 'イギリス英語', '経済産業省', 'ポルトガル語', 'イングランド', '江戸時代', 'オランダ語', '幕末', '明治', '大正', '国名の漢字表記一覧', 'アメリカ合衆国', '二字熟語による往来表現の一覧', '合同法 (1707年)', 'イングランド王国', 'スコットランド王国', 'グレートブリテン王国', 's:Act of Union 1707#Article 1 (name of the new kingdom)', '合同法 (1800年)', 'アイルランド王国', 'グレート・ブリテン及びアイルランド連合王国', '北アイルランド', 'アイルランド自由国', 'スコットランド', 'ウェールズ', 'イギリスのカントリー', ':en:Merriam Webster', ':en:New Oxford American Dictionary', '国際標準化機構', 'ISO 3166-2:GB', ':en:ISO 3166-1 alpha-3', 'Team GB', ':en:British nationality law', 'イギリス人', 'イングランド人', 'スコットランド人', 'ウェールズ人', ':en:People of Northern Ireland', 'アイルランド人', '英語', 'ウェールズ語', 'スコットランド・ゲール語', 'ファイル:Descriptio Prime Tabulae Europae.jpg', '地理学 (プトレマイオス)', ':en:Hibernia', "ファイル:Lenepveu, Jeanne d'Arc au siège d'Orléans.jpg", 'アルビオン', 'ノルマンディー公', 'ウィリアム1世 (イングランド王)', 'ノルマン・コンクエスト', '封建制', '王国', '経済力', '第一次バロン戦争', '第二次バロン戦争', 'フランス', '百年戦争', '英葡永久同盟', 'ばら戦争', 'ランカスター朝', '閨閥', 'ヴィルヘルム1世 (バイエルン公)', 'ジョン・カボット', '検閲', '国王至上法', ':en:Laws in Wales Acts 1535 and 1542', 'イングランド国教会', 'ユグノー戦争', ':en:Earl of Clancarty', 'アルマダの海戦', 'ハンザ同盟', 'ファイル:London.bankofengland.arp.jpg', 'イギリス東インド会社', '同君連合', 'ヘンリー・ハドソン', 'ウィリアム・バフィン', 'ピルグリム・ファーザーズ', '権利の請願', 'リシュリュー', 'チャールズ1世 (イングランド王)', 'オリバー・クロムウェル', 'ウィリアム3世 (イングランド王)', 'ルイ14世', 'イングランド銀行', ':en:Matthew Decker', 'カトリック', 'ピューリタン', 'イギリス帝国', 'ロシア帝国', '産業革命', 'アメリカ合衆国', 'ファイル:Battle of Waterloo 1815.PNG', '対仏大同盟', 'ワーテルローの戦い', 'ナポレオン戦争', 'パクス・ブリタニカ', ':en:Baron Rendlesham', 'アイルランド共和軍', 'ジョージ4世 (イギリス王)', 'フリーメーソン', '神聖ローマ帝国', 'ベルギー', '阿片戦争', 'ルイ16世', 'フォンテーヌブローの勅令', 'フランス革命', 'ナポレオン', 'プロイセン王国', 'オスマン帝国', '普墺戦争', 'キール運河', '普仏戦争', 'オスマン債務管理局', 'ドイツ帝国', '栄光ある孤立', 'エドワード7世 (イギリス王)', '1902年', '日本', '日英同盟', '第一次世界大戦', 'ヴァイマル共和政', 'バルフォア報告書', 'ラザード', '太平洋', 'ウィンザー朝', 'ジョージ5世 (イギリス王)', 'デビッド・ロイド・ジョージ', '1922年', '英愛条約', 'アイルランド', '1927年', ':en:Trustee Act 1925', ':en:Variation of Trusts Act 1958', 'イギリス議会', '世界恐慌', '投資信託', '証券取引委員会', '1939年', 'アドルフ・ヒトラー', '国家社会主義ドイツ労働者党', 'ナチス・ドイツ', 'ポーランド', 'フランス', 'バトル・オブ・ブリテン', '西部戦線 (第二次世界大戦)', '太平洋戦争', '民主党 (アメリカ)', 'フランクリン・ルーズベルト', '大西洋憲章', 'ウィンストン・チャーチル', '挙国一致内閣', '第二次世界大戦', 'イギリス軍', 'ハンブルク', 'ハノーファー', '西ドイツ', 'オーストリア', 'オランダ', '戦間期', '1945年', '冷戦', '資本主義', '自由主義', '西側諸国', 'ソビエト連邦', '労働党 (イギリス)', 'クレメント・アトリー', 'ゆりかごから墓場まで', '福祉国家', 'ブレトンウッズ協定', '英国病', '景気後退', 'ゼネラル・エレクトリック', '産業革命', 'イギリス領インド帝国', 'インド', '印パ分離独立', '1948年', 'スリランカ', '1948年', 'ビルマ', '1957年', 'マレーシア', '1960年代', 'アフリカ', '1960年', 'ナイジェリア', '1962年', 'ウガンダ', '1963年', 'ケニア', '1964年', 'マラウイ', 'ザンビア', '1961年', '南アフリカ共和国', '1966年', 'ローデシア', 'アパルトヘイト', '1956年', 'エジプト', 'スエズ運河', 'イスラエル', '第二次中東戦争', '地中海', '紅海', '1971年', 'バーレーン', 'カタール', 'アラブ首長国連邦', '香港', 'トウ小平', '中華人民共和国', '香港返還', 'イギリス帝国', '1964年', 'ハロルド・ウィルソン', '1969年', 'イングランド', 'ウェールズ', 'スコットランド', '1973年', '北アイルランド', '妊娠中絶', '死刑', '同性愛', 'ソドミー法', 'スターリング・ポンド', '放送大学', '大学通信教育', 'オープン大学', '保守党 (イギリス)', 'マーガレット・サッチャー', '新自由主義', '構造改革', 'ネオリベラリズム', 'サッチャリズム', '民営化', '行政改革', '規制緩和', '小さな政府', '自由主義国家論', '失業', '金融', 'ジョン・メージャー', 'トニー・ブレア', '市場', '政策', '第三の道', '1998年', '死刑', 'クール・ブリタニア', '文化政策', '21世紀', 'ゴードン・ブラウン', 'デーヴィッド・キャメロン', '2014年', '同性結婚', '2016年', '6月23日', 'イギリスの欧州連合離脱是非を問う国民投票', 'イギリスの欧州連合離脱', 'テリー ...
