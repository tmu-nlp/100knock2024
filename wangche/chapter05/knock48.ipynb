# %% [markdown]
# 48. 名詞から根へのパスの抽出
#
# 文中のすべての名詞を含む文節に対し，その文節から構文木の根に至るパスを抽出せよ． ただし，構文木上のパスは以下の仕様を満たすものとする．
#
# 各文節は（表層形の）形態素列で表現する
# パスの開始文節から終了文節に至るまで，各文節の表現を” -> “で連結する
# 「ジョン・マッカーシーはAIに関する最初の会議で人工知能という用語を作り出した。」という例文を考える． CaboChaを係り受け解析に用いた場合，次のような出力が得られると思われる．
#
# ジョンマッカーシーは -> 作り出した
# AIに関する -> 最初の -> 会議で -> 作り出した
# 最初の -> 会議で -> 作り出した
# 会議で -> 作り出した
# 人工知能という -> 用語を -> 作り出した
# 用語を -> 作り出した

# %%
class Morph:
    def __init__(self, surface, base, pos, pos1):
        self.surface = surface  # 表層形
        self.base = base        # 基本形
        self.pos = pos          # 品詞
        self.pos1 = pos1        # 品詞細分類1

    def __str__(self):
        return f"surface: {self.surface}, base: {self.base}, pos: {self.pos}, pos1: {self.pos1}"

class Chunk:
    def __init__(self, morphs=None, dst=-1):
        self.morphs = morphs if morphs else []  # 形態素（Morphオブジェクト）のリスト
        self.dst = dst  # 係り先文節インデックス番号
        self.srcs = []  # 係り元文節インデックス番号のリスト

    def __str__(self):
        morphs_surface = ''.join([morph.surface for morph in self.morphs])
        return f"Chunk: {morphs_surface}, dst: {self.dst}, srcs: {self.srcs}"

    def get_text(self):
        return ''.join([morph.surface for morph in self.morphs if morph.pos != '記号'])

def parse_cabocha_output(parsed_file):
    sentences = []
    with open(parsed_file, 'r', encoding='utf-8') as f:
        chunks = {}
        chunk = None
        for line in f:
            if line == 'EOS\n':
                if chunk is not None:
                    chunks[chunk_idx] = chunk
                if chunks:
                    sorted_chunks = sorted(chunks.items())
                    sentence = [chunk for idx, chunk in sorted_chunks]
                    for idx, chunk in sorted_chunks:
                        if chunk.dst != -1:
                            sentence[chunk.dst].srcs.append(idx)
                    sentences.append(sentence)
                chunks = {}
                chunk = None
            elif line[0] == '*':
                if chunk is not None:
                    chunks[chunk_idx] = chunk
                cols = line.split(' ')
                chunk_idx = int(cols[1])
                dst = int(cols[2].rstrip('D'))
                chunk = Chunk(dst=dst)
            else:
                surface, feature = line.split('\t')
                features = feature.split(',')
                if len(features) >= 7:
                    morph = Morph(surface, features[6], features[0], features[1])
                    chunk.morphs.append(morph)
    return sentences

def extract_paths_to_root(parsed_file):
    sentences = parse_cabocha_output(parsed_file)
    paths = []
    for sentence in sentences:
        for idx, chunk in enumerate(sentence):
            if any(morph.pos == '名詞' for morph in chunk.morphs):
                path = []
                current_chunk = chunk
                while current_chunk is not None:
                    path.append(current_chunk.get_text())
                    if current_chunk.dst != -1:
                        current_chunk = sentence[current_chunk.dst]
                    else:
                        current_chunk = None
                paths.append(' -> '.join(path))
    return paths

# 指定解析結果ファイルのパス
parsed_file = 'ai.ja.txt.parsed'

# 名詞を含む文節から根へのパスを抽出
paths = extract_paths_to_root(parsed_file)

# 結果を表示
for path in paths:
    print(path)
# Out:
# 人工知能 -> 語
# じんこうちのう -> 語
# AI -> エーアイとは -> 語
# エーアイとは -> 語
# 計算 -> という -> 道具を -> 用いて -> 研究する -> 計算機科学 -> の -> 一分野を -> 指す -> 語
# 概念と -> 道具を -> 用いて -> 研究する -> 計算機科学 -> の -> 一分野を -> 指す -> 語
# コンピュータ -> という -> 道具を -> 用いて -> 研究する -> 計算機科学 -> の -> 一分野を -> 指す -> 語
# 道具を -> 用いて -> 研究する -> 計算機科学 -> の -> 一分野を -> 指す -> 語
# 知能を -> 研究する -> 計算機科学 -> の -> 一分野を -> 指す -> 語
# 研究する -> 計算機科学 -> の -> 一分野を -> 指す -> 語
# 計算機科学 -> の -> 一分野を -> 指す -> 語
# 一分野を -> 指す -> 語
# 語
# 言語の -> 推論 -> 問題解決などの -> 知的行動を -> 代わって -> 行わせる -> 技術または -> 研究分野とも -> される
# 理解や -> 推論 -> 問題解決などの -> 知的行動を -> 代わって -> 行わせる -> 技術または -> 研究分野とも -> される
# 推論 -> 問題解決などの -> 知的行動を -> 代わって -> 行わせる -> 技術または -> 研究分野とも -> される
# 問題解決などの -> 知的行動を -> 代わって -> 行わせる -> 技術または -> 研究分野とも -> される
# 知的行動を -> 代わって -> 行わせる -> 技術または -> 研究分野とも -> される
# 人間に -> 代わって -> 行わせる -> 技術または -> 研究分野とも -> される
# コンピューターに -> 行わせる -> 技術または -> 研究分野とも -> される
# 技術または -> 研究分野とも -> される
# 計算機 -> コンピュータによる -> 情報処理システムの -> 実現に関する -> 研究分野とも -> される
# コンピュータによる -> 情報処理システムの -> 実現に関する -> 研究分野とも -> される
# 知的な -> 情報処理システムの -> 実現に関する -> 研究分野とも -> される
# 情報処理システムの -> 実現に関する -> 研究分野とも -> される
# 設計や -> 実現に関する -> 研究分野とも -> される
# 実現に関する -> 研究分野とも -> される
# 研究分野とも -> される
# 日本大百科全書(ニッポニカ)』の -> 解説で -> 述べている
# 解説で -> 述べている
# 情報工学者通信工学者の -> 佐藤理史は -> 述べている
# 佐藤理史は -> 述べている
# 次のように -> 述べている
# 人間の -> 知的能力を -> 実現する -> 技術ソフトウェアコンピュータシステム
# 知的能力を -> 実現する -> 技術ソフトウェアコンピュータシステム
# コンピュータ上で -> 実現する -> 技術ソフトウェアコンピュータシステム
# 実現する -> 技術ソフトウェアコンピュータシステム
# 様々な -> 技術ソフトウェアコンピュータシステム
# 技術ソフトウェアコンピュータシステム
# 応用例は -> ある
# 自然言語処理 -> 機械翻訳かな漢字変換構文解析等 -> 専門家の -> 推論判断を -> 模倣する -> エキスパートシステム -> 画像認識等が -> ある
# 機械翻訳かな漢字変換構文解析等 -> 専門家の -> 推論判断を -> 模倣する -> エキスパートシステム -> 画像認識等が -> ある
# 専門家の -> 推論判断を -> 模倣する -> エキスパートシステム -> 画像認識等が -> ある
# 推論判断を -> 模倣する -> エキスパートシステム -> 画像認識等が -> ある
# 模倣する -> エキスパートシステム -> 画像認識等が -> ある
# エキスパートシステム -> 画像認識等が -> ある
# 画像データを -> 解析して -> 検出抽出したりする -> 画像認識等が -> ある
# 解析して -> 検出抽出したりする -> 画像認識等が -> ある
# 特定の -> パターンを -> 検出抽出したりする -> 画像認識等が -> ある
# パターンを -> 検出抽出したりする -> 画像認識等が -> ある
# 検出抽出したりする -> 画像認識等が -> ある
# 画像認識等が -> ある
# 1956年に -> 命名された
# ダートマス会議で -> 命名された
# ジョンマッカーシーにより -> 命名された
# 命名された
# 現在では -> 使われている
# 記号処理を -> 用いた -> 知能の -> 記述を -> する -> 研究での -> アプローチという -> 意味あいでも -> 使われている
# 知能の -> 記述を -> する -> 研究での -> アプローチという -> 意味あいでも -> 使われている
# 記述を -> する -> 研究での -> アプローチという -> 意味あいでも -> 使われている
# 主体と -> する -> 研究での -> アプローチという -> 意味あいでも -> 使われている
# 情報処理や -> 研究での -> アプローチという -> 意味あいでも -> 使われている
# 研究での -> アプローチという -> 意味あいでも -> 使われている
# アプローチという -> 意味あいでも -> 使われている
# 意味あいでも -> 使われている
# 家庭用電気機械器具の -> 制御システムや -> 思考ルーチンも -> 呼ばれる -> ことも -> ある
# 制御システムや -> 思考ルーチンも -> 呼ばれる -> ことも -> ある
# ゲームソフトの -> 思考ルーチンも -> 呼ばれる -> ことも -> ある
# 思考ルーチンも -> 呼ばれる -> ことも -> ある
# ことも -> ある
# プログラミング言語による -> という -> カウンセラーを -> 模倣した -> プログラム -> 出されるが -> 困難視されている
# カウンセラーを -> 模倣した -> プログラム -> 出されるが -> 困難視されている
# 模倣した -> プログラム -> 出されるが -> 困難視されている
# プログラム -> 出されるが -> 困難視されている
# 人工無脳が -> 出されるが -> 困難視されている
# 引き合いに -> 出されるが -> 困難視されている
# 計算機に -> させようという -> エキスパートシステムと -> 呼ばれる -> 研究情報処理システムの -> 実現は -> 困難視されている
# 人間の -> 専門家の -> 役割を -> させようという -> エキスパートシステムと -> 呼ばれる -> 研究情報処理システムの -> 実現は -> 困難視されている
# 専門家の -> 役割を -> させようという -> エキスパートシステムと -> 呼ばれる -> 研究情報処理システムの -> 実現は -> 困難視されている
# 役割を -> させようという -> エキスパートシステムと -> 呼ばれる -> 研究情報処理システムの -> 実現は -> 困難視されている
# エキスパートシステムと -> 呼ばれる -> 研究情報処理システムの -> 実現は -> 困難視されている
# 研究情報処理システムの -> 実現は -> 困難視されている
# 実現は -> 困難視されている
# 人間が -> 持つ -> 常識の -> 記述が -> なり -> 困難視されている
# 暗黙に -> 持つ -> 常識の -> 記述が -> なり -> 困難視されている
# 常識の -> 記述が -> なり -> 困難視されている
# 記述が -> なり -> 困難視されている
# 問題と -> なり -> 困難視されている
# 実用への -> 利用が -> 困難視されている
# 利用が -> 困難視されている
# 困難視されている
# 人工的な -> 知能の -> 実現への -> アプローチとしては -> 知られているが -> ある
# 知能の -> 実現への -> アプローチとしては -> 知られているが -> ある
# 実現への -> アプローチとしては -> 知られているが -> ある
# アプローチとしては -> 知られているが -> ある
# ファジィ理論や -> ニューラルネットワークなどのような -> アプローチも -> 知られているが -> ある
# ニューラルネットワークなどのような -> アプローチも -> 知られているが -> ある
# アプローチも -> 知られているが -> ある
# 従来の -> 人工知能である -> (GoodOldFashionedAI)との -> 差は -> ある
# 人工知能である -> (GoodOldFashionedAI)との -> 差は -> ある
# (GoodOldFashionedAI)との -> 差は -> ある
# 差は -> ある
# 記述の -> 記号的明示性に -> ある
# 記号的明示性に -> ある
# その後 -> 集めた
# サポートベクターマシンが -> 集めた
# 注目を -> 集めた
# 自らの -> 経験を -> 行う -> 強化学習という -> 手法も -> ある
# 経験を -> 行う -> 強化学習という -> 手法も -> ある
# 元に -> 行う -> 強化学習という -> 手法も -> ある
# 学習を -> 行う -> 強化学習という -> 手法も -> ある
# 強化学習という -> 手法も -> ある
# 手法も -> ある
# 宇宙において -> 実装するという -> ことは -> 作業である
# 知性とは -> 形質である -> レイカーツワイルという -> 言葉通り -> 実装するという -> ことは -> 作業である
# 強力な -> 形質である -> レイカーツワイルという -> 言葉通り -> 実装するという -> ことは -> 作業である
# 形質である -> レイカーツワイルという -> 言葉通り -> 実装するという -> ことは -> 作業である
# レイカーツワイルという -> 言葉通り -> 実装するという -> ことは -> 作業である
# 言葉通り -> 実装するという -> ことは -> 作業である
# 知性を -> 表現し -> 実装するという -> ことは -> 作業である
# 機械的に -> 表現し -> 実装するという -> ことは -> 作業である
# 表現し -> 実装するという -> ことは -> 作業である
# 実装するという -> ことは -> 作業である
# ことは -> 作業である
# 重要な -> 作業である
# 作業である
# 2006年の -> ディープラーニング -> 登場と -> 登場により -> 行った
# ディープラーニング -> 登場と -> 登場により -> 行った
# 深層学習の -> 登場と -> 登場により -> 行った
# 登場と -> 登場により -> 行った
# 2010年代 -> 以降の -> ビッグデータの -> 登場により -> 行った
# 以降の -> ビッグデータの -> 登場により -> 行った
# ビッグデータの -> 登場により -> 行った
# 登場により -> 行った
# 一過性の -> 流行を -> 超えて -> 浸透して -> 行った
# 流行を -> 超えて -> 浸透して -> 行った
# 社会に -> 浸透して -> 行った
# 浸透して -> 行った
# 2016年から -> 2017年にかけて -> 導入した -> AIが -> 完全情報ゲームである -> 囲碁などの -> トップ棋士 -> プレイヤーも -> 破り -> なった
# 2017年にかけて -> 導入した -> AIが -> 完全情報ゲームである -> 囲碁などの -> トップ棋士 -> プレイヤーも -> 破り -> なった
# ディープラーニングを -> 導入した -> AIが -> 完全情報ゲームである -> 囲碁などの -> トップ棋士 -> プレイヤーも -> 破り -> なった
# 導入した -> AIが -> 完全情報ゲームである -> 囲碁などの -> トップ棋士 -> プレイヤーも -> 破り -> なった
# AIが -> 完全情報ゲームである -> 囲碁などの -> トップ棋士 -> プレイヤーも -> 破り -> なった
# 完全情報ゲームである -> 囲碁などの -> トップ棋士 -> プレイヤーも -> 破り -> なった
# 囲碁などの -> トップ棋士 -> プレイヤーも -> 破り -> なった
# トップ棋士 -> プレイヤーも -> 破り -> なった
# 不完全情報ゲームである -> ポーカーの -> 世界トップクラスの -> プレイヤーも -> 破り -> なった
# ポーカーの -> 世界トップクラスの -> プレイヤーも -> 破り -> なった
# 世界トップクラスの -> プレイヤーも -> 破り -> なった
# プレイヤーも -> 破り -> なった
# 麻雀では -> なった
# MicrosoftSuphx(SuperPhoenix)」が -> 到達するなど -> なった
# AIとして -> 到達するなど -> なった
# 十段に -> 到達するなど -> なった
# 到達するなど -> なった
# 時代の -> 最先端技術と -> なった
# 最先端技術と -> なった
# 第２次人工知能ブームでの -> 人工知能は -> 呼ばれ -> ある
# 人工知能は -> 呼ばれ -> ある
# 機械学習と -> 呼ばれ -> ある
# 以下のような -> ものが -> ある
# ものが -> ある
# 計算知能 -> CIは -> システム
# CIは -> システム
# 開発や -> 学習を -> 繰り返す -> ことを -> している -> 例えば -> システム
# 学習を -> 繰り返す -> ことを -> している -> 例えば -> システム
# ことを -> している -> 例えば -> システム
# 基本と -> している -> 例えば -> システム
# パラメータ調整 -> システム
# コネクショニズムの -> システム
# システム
# 学習は -> 手法であり -> 関係している
# 経験に -> 基づく -> 手法であり -> 関係している
# 手法であり -> 関係している
# 非記号的AI -> 美しくない -> ソフトコンピューティングと -> 関係している
# AI -> ソフトコンピューティングと -> 関係している
# ソフトコンピューティングと -> 関係している
# 関係している
# 手法としては -> ある
# 以下の -> ものが -> ある
# ものが -> ある
# これらを -> 統合した -> 知的システムを -> 作る -> 試みも -> なされている
# 統合した -> 知的システムを -> 作る -> 試みも -> なされている
# 知的システムを -> 作る -> 試みも -> なされている
# 試みも -> なされている
# ACT-Rでは -> 生成する
# エキスパートの -> 推論ルールを -> 生成する
# 推論ルールを -> 生成する
# 統計的学習を -> 生成する
# 元に -> 生成する
# ニューラルネットワークや -> 生成規則を通して -> 生成する
# 生成規則を通して -> 生成する
# 生成する
# 第3次人工知能ブームでは -> 行われている
# ディープラーニングが -> 画像認識 -> テキスト解析 -> 音声認識など -> 領域で -> 上回る -> 精度を -> 出しており -> 行われている
# 画像認識 -> テキスト解析 -> 音声認識など -> 領域で -> 上回る -> 精度を -> 出しており -> 行われている
# テキスト解析 -> 音声認識など -> 領域で -> 上回る -> 精度を -> 出しており -> 行われている
# 音声認識など -> 領域で -> 上回る -> 精度を -> 出しており -> 行われている
# 様々な -> 領域で -> 上回る -> 精度を -> 出しており -> 行われている
# 領域で -> 上回る -> 精度を -> 出しており -> 行われている
# 第2次人工知能ブームの -> 人工知能を -> 上回る -> 精度を -> 出しており -> 行われている
# 人工知能を -> 上回る -> 精度を -> 出しており -> 行われている
# 精度を -> 出しており -> 行われている
# ディープラーニングの -> 研究が -> 行われている
# 研究が -> 行われている
# 盛んに -> 行われている
# 最近では -> 活躍している
# DQN -> CNN -> RNN -> GANと -> ディープラーニングの -> 派生が -> でて -> 活躍している
# CNN -> RNN -> GANと -> ディープラーニングの -> 派生が -> でて -> 活躍している
# RNN -> GANと -> ディープラーニングの -> 派生が -> でて -> 活躍している
# GANと -> ディープラーニングの -> 派生が -> でて -> 活躍している
# 様々な -> ディープラーニングの -> 派生が -> でて -> 活躍している
# ディープラーニングの -> 派生が -> でて -> 活躍している
# 派生が -> でて -> 活躍している
# 各分野で -> 活躍している
# 活躍している
# GAN -> 敵対的生成ネットワークは -> 見せている
# 敵対的生成ネットワークは -> 見せている
# ディープラーニングが -> だしている -> ことに -> 加えて -> 見せている
# 認識や -> 予測などの -> 分野で -> だしている -> ことに -> 加えて -> 見せている
# 予測などの -> 分野で -> だしている -> ことに -> 加えて -> 見せている
# 分野で -> だしている -> ことに -> 加えて -> 見せている
# 成果を -> だしている -> ことに -> 加えて -> 見せている
# ことに -> 加えて -> 見せている
# 画像の -> 生成技術において -> 見せている
# 生成技術において -> 見せている
# 進化を -> 見せている
# 森正弥は -> 指摘している
# これらの -> 成果を -> 背景に -> 広がっており -> 始まっていると -> 指摘している
# 成果を -> 背景に -> 広がっており -> 始まっていると -> 指摘している
# 背景に -> 広がっており -> 始まっていると -> 指摘している
# 従来の -> 人工知能の -> 応用分野が -> 広がっており -> 始まっていると -> 指摘している
# 人工知能の -> 応用分野が -> 広がっており -> 始まっていると -> 指摘している
# 応用分野が -> 広がっており -> 始まっていると -> 指摘している
# CreativeAIという -> コンテンツ生成を -> 行っていく -> 応用も -> 始まっていると -> 指摘している
# コンテンツ生成を -> 行っていく -> 応用も -> 始まっていると -> 指摘している
# 応用も -> 始まっていると -> 指摘している
# 指摘している
# AIの -> 構築が -> 長い間 -> 試みられてきているが -> なってきた
# 構築が -> 長い間 -> 試みられてきているが -> なってきた
# 長い間 -> 試みられてきているが -> なってきた
# シンボルグラウンディング問題と -> フレーム問題の -> 解決が -> なってきた
# フレーム問題の -> 解決が -> なってきた
# 解決が -> なってきた
# 壁と -> なってきた
# 17世紀 -> 初め -> 機械論
# 初め -> 機械論
# ルネ・デカルトは -> 機械論
# 動物の -> 身体が -> 提唱した -> 機械論
# 身体が -> 提唱した -> 機械論
# ただの -> 機械であると -> 提唱した -> 機械論
# 複雑な -> 機械であると -> 提唱した -> 機械論
# 機械であると -> 提唱した -> 機械論
# 提唱した -> 機械論
# 機械論
# ブレーズ・パスカルは -> 製作した
# 1642年 -> 製作した
# 最初の -> 機械式計算機を -> 製作した
# 機械式計算機を -> 製作した
# 製作した
# チャールズバベッジと -> エイダ・ラブレスは -> 行った
# エイダ・ラブレスは -> 行った
# プログラム可能な -> 機械式計算機の -> 開発を -> 行った
# 機械式計算機の -> 開発を -> 行った
# 開発を -> 行った
# バートランド・ラッセルと -> アルフレッドノースホワイトヘッドは -> もたらした
# アルフレッドノースホワイトヘッドは -> もたらした
# 数学原理を -> 出版し -> もたらした
# 出版し -> もたらした
# 形式論理に -> もたらした
# 革命を -> もたらした
# ウォーレン・マカロックと -> ウォルター・ピッツは -> 発表し -> 築いた
# ウォルター・ピッツは -> 発表し -> 築いた
# 神経活動に -> 内在する -> アイデアの -> 論理計算と -> 題する -> 論文を -> 発表し -> 築いた
# 内在する -> アイデアの -> 論理計算と -> 題する -> 論文を -> 発表し -> 築いた
# アイデアの -> 論理計算と -> 題する -> 論文を -> 発表し -> 築いた
# 論理計算と -> 題する -> 論文を -> 発表し -> 築いた
# 論文を -> 発表し -> 築いた
# 1943年に -> 発表し -> 築いた
# 発表し -> 築いた
# ニューラルネットワークの -> 基礎を -> 築いた
# 基礎を -> 築いた
# 1950年代に -> なると -> 出始めた
# AIに関して -> 出始めた
# 活発な -> 成果が -> 出始めた
# 成果が -> 出始めた
# ジョンマッカーシーは -> 作り出した
# AIに関する -> 最初の -> 会議で -> 作り出した
# 最初の -> 会議で -> 作り出した
# 会議で -> 作り出した
# 人工知能という -> 用語を -> 作り出した
# 用語を -> 作り出した
# 彼はまた -> 開発した
# プログラミング言語を -> 開発した
# 開発した
# 知的ふるまいに関する -> テストを -> 可能にする -> 方法として -> 導入した
# テストを -> 可能にする -> 方法として -> 導入した
# 可能にする -> 方法として -> 導入した
# 方法として -> 導入した
# アランチューリングは -> 導入した
# チューリングテストを -> 導入した
# 導入した
# ジョセフワイゼンバウムはを -> 構築した
# 構築した
# これは -> おしゃべりロボットである
# 来談者中心療法を -> 行う -> おしゃべりロボットである
# おしゃべりロボットである
# 1956年に -> 行われた -> 提案書において -> 使用され -> 創立された
# ダートマス会議開催の -> 提案書において -> 使用され -> 創立された
# 提案書において -> 使用され -> 創立された
# 人類史上 -> 用語として -> 使用され -> 創立された
# 用語として -> 使用され -> 創立された
# 使用され -> 創立された
# 新たな -> 分野として -> 創立された
# 分野として -> 創立された
# 創立された
# 1960年代と -> 1970年代の -> 間に -> 示した
# 1970年代の -> 間に -> 示した
# 間に -> 示した
# ジョエルモーゼスは -> 示した
# プログラム中で -> 示した
# 積分問題での -> 記号的推論の -> パワーを -> 示した
# 記号的推論の -> パワーを -> 示した
# パワーを -> 示した
# マービン・ミンスキーと -> シーモア・パパートは -> 示し -> 開発した
# シーモア・パパートは -> 示し -> 開発した
# パーセプトロンを -> 出版して -> 示し -> 開発した
# 出版して -> 示し -> 開発した
# 単純な -> ニューラルネットの -> 限界を -> 示し -> 開発した
# ニューラルネットの -> 限界を -> 示し -> 開発した
# 限界を -> 示し -> 開発した
# アランカルメラウアーは -> 開発した
# プログラミング言語を -> 開発した
# 開発した
# テッドショートリッフェは -> 示した
# 医学的診断と -> 療法における -> ルールベースシステムを -> 構築し -> 示した
# 療法における -> ルールベースシステムを -> 構築し -> 示した
# ルールベースシステムを -> 構築し -> 示した
# 構築し -> 示した
# 知識表現と -> 推論の -> パワーを -> 示した
# 推論の -> パワーを -> 示した
# パワーを -> 示した
# これは -> ある
# 最初の -> エキスパートシステムと -> 呼ばれる -> ことも -> ある
# エキスパートシステムと -> 呼ばれる -> ことも -> ある
# ことも -> ある
# ハンスモラベックは -> 障害物の
# 障害物の
# コースを -> 走行する -> 最初の -> コンピューター制御の -> 乗り物を -> 開発した
# 自律的に -> 走行する -> 最初の -> コンピューター制御の -> 乗り物を -> 開発した
# 走行する -> 最初の -> コンピューター制御の -> 乗り物を -> 開発した
# 最初の -> コンピューター制御の -> 乗り物を -> 開発した
# コンピューター制御の -> 乗り物を -> 開発した
# 乗り物を -> 開発した
# 開発した
# 1980年代に -> 使われるようになった
# ニューラルネットワークは -> 使われるようになった
# バックプロパゲーションアルゴリズムによって -> 使われるようになった
# 使われるようになった
# 時代に -> 提唱した
# ロドニー・ブルックスが -> 提唱した
# 知能には -> 提唱した
# 身体が -> 必須との -> 学説 -> 身体性を -> 提唱した
# 必須との -> 学説 -> 身体性を -> 提唱した
# 学説 -> 身体性を -> 提唱した
# 身体性を -> 提唱した
# 提唱した
# 1990年代は -> 上げた
# AIの -> 多くの -> 分野で -> 上げた
# 多くの -> 分野で -> 上げた
# 分野で -> 上げた
# 様々な -> アプリケーションが -> 上げた
# アプリケーションが -> 上げた
# 成果を -> 上げた
# ボードゲームでは -> 目覚ましく -> 敗れた
# 1992年に -> 開発し -> 敗れた
# IBMは -> 開発し -> 敗れた
# 世界チャンピオンに -> 匹敵する -> バックギャモン専用コンピュータTDギャモンを -> 開発し -> 敗れた
# 匹敵する -> バックギャモン専用コンピュータTDギャモンを -> 開発し -> 敗れた
# バックギャモン専用コンピュータTDギャモンを -> 開発し -> 敗れた
# 開発し -> 敗れた
# IBMの -> チェス専用コンピュータ・ディープ・ブルーは -> 敗れた
# チェス専用コンピュータ・ディープ・ブルーは -> 敗れた
# 1997年 -> 5月に -> 打ち負かし -> 敗れた
# 5月に -> 打ち負かし -> 敗れた
# ガルリ・カスパロフを -> 打ち負かし -> 敗れた
# 同年 -> 8月には -> 敗れた
# 8月には -> 敗れた
# オセロで -> 敗れた
# 日本電気の -> オセロ専用コンピュータ・ロジステロに -> 敗れた
# オセロ専用コンピュータ・ロジステロに -> 敗れた
# 世界チャンピオンの -> 村上健が -> 敗れた
# 村上健が -> 敗れた
# 国防高等研究計画局は -> 明らかにした
# 最初の -> 湾岸戦争において -> スケジューリングするのに -> 使い -> 上回った -> ことを -> 明らかにした
# 湾岸戦争において -> スケジューリングするのに -> 使い -> 上回った -> ことを -> 明らかにした
# ユニットを -> スケジューリングするのに -> 使い -> 上回った -> ことを -> 明らかにした
# スケジューリングするのに -> 使い -> 上回った -> ことを -> 明らかにした
# AIを -> 使い -> 上回った -> ことを -> 明らかにした
# これによって -> 省かれた -> コストが -> 上回った -> ことを -> 明らかにした
# コストが -> 上回った -> ことを -> 明らかにした
# 1950年代以来の -> AI研究への -> 政府の -> 投資全額を -> 上回った -> ことを -> 明らかにした
# AI研究への -> 政府の -> 投資全額を -> 上回った -> ことを -> 明らかにした
# 政府の -> 投資全額を -> 上回った -> ことを -> 明らかにした
# 投資全額を -> 上回った -> ことを -> 明らかにした
# ことを -> 明らかにした
# 明らかにした
# 日本では -> 発生したが -> 指摘された
# 甘利俊一日本学士院会員らが -> 啓蒙し -> 発生したが -> 指摘された
# 精力的に -> 啓蒙し -> 発生したが -> 指摘された
# 啓蒙し -> 発生したが -> 指摘された
# 優秀な -> 成果も -> 発生したが -> 指摘された
# 成果も -> 発生したが -> 指摘された
# 発生したが -> 指摘された
# 論理の -> ブラックボックス性が -> 指摘された
# ブラックボックス性が -> 指摘された
# 指摘された
# 1998年には -> 提唱されたが -> 開始された
# 非構造化データ形式の -> 国際規格である -> XMLが -> 提唱されたが -> 開始された
# 国際規格である -> XMLが -> 提唱されたが -> 開始された
# XMLが -> 提唱されたが -> 開始された
# 提唱されたが -> 開始された
# ここから -> 適用し -> 行わせる -> 試みが -> 開始された
# Web上の -> 非構造化データに対して -> 適用し -> 行わせる -> 試みが -> 開始された
# 非構造化データに対して -> 適用し -> 行わせる -> 試みが -> 開始された
# アプリケーション別に -> 適した -> 意味付けを -> 適用し -> 行わせる -> 試みが -> 開始された
# 意味付けを -> 適用し -> 行わせる -> 試みが -> 開始された
# 適用し -> 行わせる -> 試みが -> 開始された
# 処理を -> 行わせる -> 試みが -> 開始された
# 試みが -> 開始された
# 開始された
# 同年に -> 提唱された
# W -> 3Cの -> ティム・バーナーズリーにより -> 行わせる -> セマンティック・ウェブが -> 提唱された
# 3Cの -> ティム・バーナーズリーにより -> 行わせる -> セマンティック・ウェブが -> 提唱された
# ティム・バーナーズリーにより -> 行わせる -> セマンティック・ウェブが -> 提唱された
# Webに -> 行わせる -> セマンティック・ウェブが -> 提唱された
# 知的処理を -> 行わせる -> セマンティック・ウェブが -> 提唱された
# セマンティック・ウェブが -> 提唱された
# 提唱された
# 技術は -> ものである
# Web上の -> データに -> 付加して -> 行わせる -> 方法を -> 規格化する -> ものである
# データに -> 付加して -> 行わせる -> 方法を -> 規格化する -> ものである
# 意味を -> 付加して -> 行わせる -> 方法を -> 規格化する -> ものである
# 付加して -> 行わせる -> 方法を -> 規格化する -> ものである
# コンピュータに -> 行わせる -> 方法を -> 規格化する -> ものである
# 知的処理を -> 行わせる -> 方法を -> 規格化する -> ものである
# 方法を -> 規格化する -> ものである
# 国際的に -> 規格化する -> ものである
# 規格化する -> ものである
# ものである
# 規格には -> 含まれている -> ことから -> 分かる
# 知識工学における -> オントロジーを -> 表現する -> データ形式の -> OWLも -> 含まれている -> ことから -> 分かる
# オントロジーを -> 表現する -> データ形式の -> OWLも -> 含まれている -> ことから -> 分かる
# 表現する -> データ形式の -> OWLも -> 含まれている -> ことから -> 分かる
# データ形式の -> OWLも -> 含まれている -> ことから -> 分かる
# OWLも -> 含まれている -> ことから -> 分かる
# ことから -> 分かる
# 流行した -> エキスパートシステムの -> 亜種である -> ことが -> 分かる
# エキスパートシステムの -> 亜種である -> ことが -> 分かる
# 亜種である -> ことが -> 分かる
# ことが -> 分かる
# 2000年代 -> 前半に -> 完了しているが -> していない
# 前半に -> 完了しているが -> していない
# 規格化が -> 完了しているが -> していない
# 完了しているが -> していない
# Web開発者にとっては -> していない
# 開発工数に -> 見合うだけの -> メリットが -> 見出せなかった -> ことから -> していない
# メリットが -> 見出せなかった -> ことから -> していない
# ことから -> していない
# 現在も -> していない
# 普及は -> していない
# 日本においては -> 流行した
# エキスパートシステムの -> 流行の -> 後に -> 流行した
# 流行の -> 後に -> 流行した
# 後に -> 流行した
# ニューロファジィが -> 流行した
# 流行した
# 研究が -> 進むにつれて -> 直面し -> 激変させるような -> AIに -> 至る -> ことは -> 無く -> 終焉した
# 計算リソースや -> データ量の -> 不足 -> シンボルグラウンディング問題 -> フレーム問題に -> 直面し -> 激変させるような -> AIに -> 至る -> ことは -> 無く -> 終焉した
# データ量の -> 不足 -> シンボルグラウンディング問題 -> フレーム問題に -> 直面し -> 激変させるような -> AIに -> 至る -> ことは -> 無く -> 終焉した
# 不足 -> シンボルグラウンディング問題 -> フレーム問題に -> 直面し -> 激変させるような -> AIに -> 至る -> ことは -> 無く -> 終焉した
# シンボルグラウンディング問題 -> フレーム問題に -> 直面し -> 激変させるような -> AIに -> 至る -> ことは -> 無く -> 終焉した
# フレーム問題に -> 直面し -> 激変させるような -> AIに -> 至る -> ことは -> 無く -> 終焉した
# 直面し -> 激変させるような -> AIに -> 至る -> ことは -> 無く -> 終焉した
# 産業の -> 在り方を -> 激変させるような -> AIに -> 至る -> ことは -> 無く -> 終焉した
# 在り方を -> 激変させるような -> AIに -> 至る -> ことは -> 無く -> 終焉した
# 激変させるような -> AIに -> 至る -> ことは -> 無く -> 終焉した
# AIに -> 至る -> ことは -> 無く -> 終焉した
# ことは -> 無く -> 終焉した
# ブームは -> 終焉した
# 終焉した
# 1980年代に -> 入って -> 立ち上がった
# 大企業の -> 研究所を -> 中心に -> 立ち上がった
# 研究所を -> 中心に -> 立ち上がった
# 中心に -> 立ち上がった
# 知識工学に -> 基づく -> エキスパートシステムが -> 提案されるようになり -> 立ち上がった
# エキスパートシステムが -> 提案されるようになり -> 立ち上がった
# 多数 -> 提案されるようになり -> 立ち上がった
# 提案されるようになり -> 立ち上がった
# エキスパートシステムを -> する -> AIベンチャーも -> 立ち上がった
# 専門と -> する -> AIベンチャーも -> 立ち上がった
# AIベンチャーも -> 立ち上がった
# 流行から -> 生まれた -> 究極の -> プロジェクトとして -> 挙げられる
# 究極の -> プロジェクトとして -> 挙げられる
# プロジェクトとして -> 挙げられる
# 第五世代コンピュータが -> 挙げられる
# 1982年から -> 1992年まで -> 至らなかった
# 1992年まで -> 至らなかった
# 日本は -> 至らなかった
# 国家プロジェクトとして -> 費やして -> 進めるも -> 至らなかった
# 570億円を -> 費やして -> 進めるも -> 至らなかった
# 第五世代コンピュータの -> 研究を -> 進めるも -> 至らなかった
# 研究を -> 進めるも -> 至らなかった
# 採用した -> 知識工学的手法では -> 必要で -> あり -> 至らなかった
# 知識工学的手法では -> 必要で -> あり -> 至らなかった
# 膨大な -> ルールの -> 手入力が -> 必要で -> あり -> 至らなかった
# ルールの -> 手入力が -> 必要で -> あり -> 至らなかった
# 手入力が -> 必要で -> あり -> 至らなかった
# 必要で -> あり -> 至らなかった
# 専門家間で -> 異なる -> 場合には -> あり -> 至らなかった
# 専門知識の -> 解釈が -> 異なる -> 場合には -> あり -> 至らなかった
# 解釈が -> 異なる -> 場合には -> あり -> 至らなかった
# 場合には -> あり -> 至らなかった
# 統一した -> ルール化が -> 行えない -> 等の -> 問題も -> あり -> 至らなかった
# ルール化が -> 行えない -> 等の -> 問題も -> あり -> 至らなかった
# 等の -> 問題も -> あり -> 至らなかった
# 問題も -> あり -> 至らなかった
# 実用的な -> エキスパートシステムの -> 実現には -> 至らなかった
# エキスパートシステムの -> 実現には -> 至らなかった
# 実現には -> 至らなかった
# 実現した -> 成果物は -> Prolog専用機であるが -> 見つからなかった
# 成果物は -> Prolog専用機であるが -> 見つからなかった
# Prologの -> 命令を -> 解釈して -> 実行する -> Prolog専用機であるが -> 見つからなかった
# 命令を -> 解釈して -> 実行する -> Prolog専用機であるが -> 見つからなかった
# 直接 -> 解釈して -> 実行する -> Prolog専用機であるが -> 見つからなかった
# CPUの -> ハードウェアの -> 機構で -> 解釈して -> 実行する -> Prolog専用機であるが -> 見つからなかった
# ハードウェアの -> 機構で -> 解釈して -> 実行する -> Prolog専用機であるが -> 見つからなかった
# 機構で -> 解釈して -> 実行する -> Prolog専用機であるが -> 見つからなかった
# 解釈して -> 実行する -> Prolog専用機であるが -> 見つからなかった
# 高速に -> 実行する -> Prolog専用機であるが -> 見つからなかった
# 実行する -> Prolog専用機であるが -> 見つからなかった
# 並列型の -> Prolog専用機であるが -> 見つからなかった
# Prolog専用機であるが -> 見つからなかった
# 商業的な -> 意味で -> 見つからなかった
# 意味で -> 見つからなかった
# 応用先が -> 見つからなかった
# 1980年代 -> 後半から -> 中頃にかけて -> 用いられてきた -> ON/OFF制御 -> PID制御 -> 現代制御の -> 問題を -> 克服する -> ため -> 迎えた
# 後半から -> 中頃にかけて -> 用いられてきた -> ON/OFF制御 -> PID制御 -> 現代制御の -> 問題を -> 克服する -> ため -> 迎えた
# 1990年代 -> 中頃にかけて -> 用いられてきた -> ON/OFF制御 -> PID制御 -> 現代制御の -> 問題を -> 克服する -> ため -> 迎えた
# 中頃にかけて -> 用いられてきた -> ON/OFF制御 -> PID制御 -> 現代制御の -> 問題を -> 克服する -> ため -> 迎えた
# 従来から -> 用いられてきた -> ON/OFF制御 -> PID制御 -> 現代制御の -> 問題を -> 克服する -> ため -> 迎えた
# 電子制御の -> 手法として -> 用いられてきた -> ON/OFF制御 -> PID制御 -> 現代制御の -> 問題を -> 克服する -> ため -> 迎えた
# 手法として -> 用いられてきた -> ON/OFF制御 -> PID制御 -> 現代制御の -> 問題を -> 克服する -> ため -> 迎えた
# ON/OFF制御 -> PID制御 -> 現代制御の -> 問題を -> 克服する -> ため -> 迎えた
# PID制御 -> 現代制御の -> 問題を -> 克服する -> ため -> 迎えた
# 現代制御の -> 問題を -> 克服する -> ため -> 迎えた
# 問題を -> 克服する -> ため -> 迎えた
# 克服する -> ため -> 迎えた
# ため -> 迎えた
# 知的制御が -> 研究され -> 迎えた
# 盛んに -> 研究され -> 迎えた
# 研究され -> 迎えた
# 知識工学的な -> ルールを -> 用いる -> ファジィ制御 -> ニューラルネットワーク -> ニューロファジィという -> 手法が -> 迎えた
# ルールを -> 用いる -> ファジィ制御 -> ニューラルネットワーク -> ニューロファジィという -> 手法が -> 迎えた
# ファジィ制御 -> ニューラルネットワーク -> ニューロファジィという -> 手法が -> 迎えた
# データの -> 特徴を -> 学習して -> 分類する -> ニューラルネットワーク -> ニューロファジィという -> 手法が -> 迎えた
# 特徴を -> 学習して -> 分類する -> ニューラルネットワーク -> ニューロファジィという -> 手法が -> 迎えた
# 学習して -> 分類する -> ニューラルネットワーク -> ニューロファジィという -> 手法が -> 迎えた
# 分類する -> ニューラルネットワーク -> ニューロファジィという -> 手法が -> 迎えた
# ニューラルネットワーク -> ニューロファジィという -> 手法が -> 迎えた
# 2つを -> 融合した -> ニューロファジィという -> 手法が -> 迎えた
# 融合した -> ニューロファジィという -> 手法が -> 迎えた
# ニューロファジィという -> 手法が -> 迎えた
# 手法が -> 迎えた
# 日本を -> 中心に -> 迎えた
# 中心に -> 迎えた
# ブームを -> 迎えた
# バブル期の -> 高級路線に -> 合わせて -> 増やし -> 最適化する -> モデルが -> 発売され始めた
# 高級路線に -> 合わせて -> 増やし -> 最適化する -> モデルが -> 発売され始めた
# 白物家電製品でも -> 増やし -> 最適化する -> モデルが -> 発売され始めた
# センサの -> 個数と -> 種類を -> 増やし -> 最適化する -> モデルが -> 発売され始めた
# 個数と -> 種類を -> 増やし -> 最適化する -> モデルが -> 発売され始めた
# 種類を -> 増やし -> 最適化する -> モデルが -> 発売され始めた
# 大幅に -> 増やし -> 最適化する -> モデルが -> 発売され始めた
# 多様な -> データを -> 元に -> 最適化する -> モデルが -> 発売され始めた
# データを -> 元に -> 最適化する -> モデルが -> 発売され始めた
# 元に -> 最適化する -> モデルが -> 発売され始めた
# 運転を -> 最適化する -> モデルが -> 発売され始めた
# 最適化する -> モデルが -> 発売され始めた
# モデルが -> 発売され始めた
# 多数 -> 発売され始めた
# 発売され始めた
# ファジィについては -> 分かっている
# 2018年までに -> 取得している -> 事から -> なっていた -> ことが -> 分かっている
# 日本が -> 取得している -> 事から -> なっていた -> ことが -> 分かっている
# 世界の -> 1/5の -> 特許を -> 取得している -> 事から -> なっていた -> ことが -> 分かっている
# 1/5の -> 特許を -> 取得している -> 事から -> なっていた -> ことが -> 分かっている
# 特許を -> 取得している -> 事から -> なっていた -> ことが -> 分かっている
# 取得している -> 事から -> なっていた -> ことが -> 分かっている
# 事から -> なっていた -> ことが -> 分かっている
# 日本で -> なっていた -> ことが -> 分かっている
# ブームと -> なっていた -> ことが -> 分かっている
# ことが -> 分かっている
# 現在の -> 白物家電では -> 用いられているが -> 意識されなくなっている
# 白物家電では -> 用いられているが -> 意識されなくなっている
# 当時より -> 発展した -> 制御技術が -> 用いられているが -> 意識されなくなっている
# 発展した -> 制御技術が -> 用いられているが -> 意識されなくなっている
# 制御技術が -> 用いられているが -> 意識されなくなっている
# 当たり前の -> ものに -> なり -> 意識されなくなっている
# ものに -> なり -> 意識されなくなっている
# 利用者には -> 意識されなくなっている
# 意識されなくなっている
# ニューロファジィが -> なった -> 1990年代には -> 行われなかった
# ブームに -> なった -> 1990年代には -> 行われなかった
# 1990年代には -> 行われなかった
# ビッグデータという -> 概念は -> 行われなかった
# 概念は -> 行われなかった
# ブロードバンド接続普及後の -> 2010年に -> 提唱された -> 産業応用は -> 行われなかった
# 2010年に -> 提唱された -> 産業応用は -> 行われなかった
# 提唱された -> 産業応用は -> 行われなかった
# データマイニングとしての -> 産業応用は -> 行われなかった
# 産業応用は -> 行われなかった
# ニューラルネットワークが -> 流行した -> 事例としては -> 事例であり -> 社会現象と -> 言える
# 一般人も -> 巻き込んで -> 流行した -> 事例としては -> 事例であり -> 社会現象と -> 言える
# 流行した -> 事例としては -> 事例であり -> 社会現象と -> 言える
# 事例としては -> 事例であり -> 社会現象と -> 言える
# 事例であり -> 社会現象と -> 言える
# 2010年代の -> ディープラーニングブームの -> 前史とも -> 言える -> 社会現象と -> 言える
# ディープラーニングブームの -> 前史とも -> 言える -> 社会現象と -> 言える
# 前史とも -> 言える -> 社会現象と -> 言える
# 社会現象と -> 言える
# 松下電器が -> 持つような -> 曖昧さを -> 活かす -> ファジィ制御についての -> 研究を -> 開始し -> 漕ぎ着けた
# 1985年頃から -> 持つような -> 曖昧さを -> 活かす -> ファジィ制御についての -> 研究を -> 開始し -> 漕ぎ着けた
# 人間が -> 持つような -> 曖昧さを -> 活かす -> ファジィ制御についての -> 研究を -> 開始し -> 漕ぎ着けた
# 持つような -> 曖昧さを -> 活かす -> ファジィ制御についての -> 研究を -> 開始し -> 漕ぎ着けた
# 曖昧さを -> 活かす -> ファジィ制御についての -> 研究を -> 開始し -> 漕ぎ着けた
# 制御に -> 活かす -> ファジィ制御についての -> 研究を -> 開始し -> 漕ぎ着けた
# ファジィ制御についての -> 研究を -> 開始し -> 漕ぎ着けた
# 研究を -> 開始し -> 漕ぎ着けた
# 開始し -> 漕ぎ着けた
# 1990年2月 -> 1日に -> 漕ぎ着けた
# 1日に -> 漕ぎ着けた
# ファジィ洗濯機第1号である -> 愛妻号Dayファジィの -> 発売に -> 漕ぎ着けた
# 愛妻号Dayファジィの -> 発売に -> 漕ぎ着けた
# 発売に -> 漕ぎ着けた
# 愛妻号Dayファジィは -> 世界初であった
# 従来よりも -> 収集した -> データに -> 基づいて -> 最適化する -> 洗濯機で -> 世界初であった
# 多数の -> センサーで -> 収集した -> データに -> 基づいて -> 最適化する -> 洗濯機で -> 世界初であった
# センサーで -> 収集した -> データに -> 基づいて -> 最適化する -> 洗濯機で -> 世界初であった
# 収集した -> データに -> 基づいて -> 最適化する -> 洗濯機で -> 世界初であった
# データに -> 基づいて -> 最適化する -> 洗濯機で -> 世界初であった
# 柔軟に -> 最適化する -> 洗濯機で -> 世界初であった
# 運転を -> 最適化する -> 洗濯機で -> 世界初であった
# 最適化する -> 洗濯機で -> 世界初であった
# 洗濯機で -> 世界初であった
# 同種の -> 洗濯機としては -> 世界初であった
# 洗濯機としては -> 世界初であった
# 世界初であった
# ファジィ制御という -> マッチした -> ことから -> 集めた
# 当時 -> マッチした -> ことから -> 集めた
# 最先端の -> 技術の -> 導入が -> マッチした -> ことから -> 集めた
# 技術の -> 導入が -> マッチした -> ことから -> 集めた
# 導入が -> マッチした -> ことから -> 集めた
# バブル期の -> 高級路線にも -> マッチした -> ことから -> 集めた
# 高級路線にも -> マッチした -> ことから -> 集めた
# マッチした -> ことから -> 集めた
# ことから -> 集めた
# ファジィは -> 集めた
# 裏方の -> 制御技術であるにも -> 関わらず -> 集めた
# 制御技術であるにも -> 関わらず -> 集めた
# 世間の -> 注目を -> 集めた
# 注目を -> 集めた
# 流行の -> 度合いは -> 程であった
# 度合いは -> 程であった
# 1990年の -> 新語流行語大賞における -> 新語部門の -> 金賞で -> 選ばれる -> 程であった
# 新語流行語大賞における -> 新語部門の -> 金賞で -> 選ばれる -> 程であった
# 新語部門の -> 金賞で -> 選ばれる -> 程であった
# 金賞で -> 選ばれる -> 程であった
# ファジィが -> 選ばれる -> 程であった
# 程であった
# その後に -> 巻き起こした
# 松下電器は -> 巻き起こした
# ファジィルールの -> チューニングを -> 自動化した -> ニューロファジィ制御を -> 開発し -> 突破して -> 評価されるだけでなく -> 巻き起こした
# 煩雑な -> チューニングを -> 自動化した -> ニューロファジィ制御を -> 開発し -> 突破して -> 評価されるだけでなく -> 巻き起こした
# チューニングを -> 自動化した -> ニューロファジィ制御を -> 開発し -> 突破して -> 評価されるだけでなく -> 巻き起こした
# 自動化した -> ニューロファジィ制御を -> 開発し -> 突破して -> 評価されるだけでなく -> 巻き起こした
# ニューロファジィ制御を -> 開発し -> 突破して -> 評価されるだけでなく -> 巻き起こした
# 開発し -> 突破して -> 評価されるだけでなく -> 巻き起こした
# 従来の -> ファジィ理論の -> 限界を -> 突破して -> 評価されるだけでなく -> 巻き起こした
# ファジィ理論の -> 限界を -> 突破して -> 評価されるだけでなく -> 巻き起こした
# 限界を -> 突破して -> 評価されるだけでなく -> 巻き起こした
# 突破して -> 評価されるだけでなく -> 巻き起こした
# 学会で -> 評価されるだけでなく -> 巻き起こした
# 評価されるだけでなく -> 巻き起こした
# 白物家電への -> 応用にも -> 成功して -> 巻き起こした
# 応用にも -> 成功して -> 巻き起こした
# 成功して -> 巻き起こした
# 更なる -> ブームを -> 巻き起こした
# ブームを -> 巻き起こした
# 松下電器の -> 試みの -> 成功を -> 受けて -> 用いる -> 製品を -> 発売した
# 試みの -> 成功を -> 受けて -> 用いる -> 製品を -> 発売した
# 成功を -> 受けて -> 用いる -> 製品を -> 発売した
# 他社も -> 用いる -> 製品を -> 発売した
# 同様の -> 知的制御を -> 用いる -> 製品を -> 発売した
# 知的制御を -> 用いる -> 製品を -> 発売した
# 製品を -> 発売した
# 多数 -> 発売した
# 発売した
# 1990年代 -> 中頃までは -> 用いられており -> 付与されていた
# 中頃までは -> 用いられており -> 付与されていた
# メーカー各社による -> 一般向けの -> 白物家電の -> 売り文句として -> 用いられており -> 付与されていた
# 一般向けの -> 白物家電の -> 売り文句として -> 用いられており -> 付与されていた
# 白物家電の -> 売り文句として -> 用いられており -> 付与されていた
# 売り文句として -> 用いられており -> 付与されていた
# 知的制御技術の -> 名称が -> 用いられており -> 付与されていた
# 名称が -> 用いられており -> 付与されていた
# 大々的に -> 用いられており -> 付与されていた
# 洗濯機の -> 製品名では -> 付与されていた
# 製品名では -> 付与されていた
# 愛妻号DAYファジィ -> 掃除機の -> 分類としては -> 付与されていた
# 掃除機の -> 分類としては -> 付与されていた
# 分類としては -> 付与されていた
# ニューロ・ファジィ掃除機 -> エアコンの -> 運転モードでは -> 付与されていた
# エアコンの -> 運転モードでは -> 付与されていた
# 運転モードでは -> 付与されていた
# ニューロ自動などの -> 名称が -> 付与されていた
# 名称が -> 付与されていた
# 付与されていた
# ニューロ -> ファジィ -> ニューロファジィという -> 手法は -> あった
# ファジィ -> ニューロファジィという -> 手法は -> あった
# ニューロファジィという -> 手法は -> あった
# 手法は -> あった
# 従来の -> オン・オフ制御や -> 作業は -> 難しくなる -> 必要が -> ある -> 現代制御等と -> 比較して -> あった
# 単純な -> オン・オフ制御や -> 作業は -> 難しくなる -> 必要が -> ある -> 現代制御等と -> 比較して -> あった
# オン・オフ制御や -> 作業は -> 難しくなる -> 必要が -> ある -> 現代制御等と -> 比較して -> あった
# 対象を -> モデル化する -> 作業は -> 難しくなる -> 必要が -> ある -> 現代制御等と -> 比較して -> あった
# 数式で -> モデル化する -> 作業は -> 難しくなる -> 必要が -> ある -> 現代制御等と -> 比較して -> あった
# 客観的に -> モデル化する -> 作業は -> 難しくなる -> 必要が -> ある -> 現代制御等と -> 比較して -> あった
# モデル化する -> 作業は -> 難しくなる -> 必要が -> ある -> 現代制御等と -> 比較して -> あった
# 作業は -> 難しくなる -> 必要が -> ある -> 現代制御等と -> 比較して -> あった
# 対象が -> 持つ -> 場合は -> 難しくなる -> 必要が -> ある -> 現代制御等と -> 比較して -> あった
# 複雑な -> 機構を -> 持つ -> 場合は -> 難しくなる -> 必要が -> ある -> 現代制御等と -> 比較して -> あった
# 機構を -> 持つ -> 場合は -> 難しくなる -> 必要が -> ある -> 現代制御等と -> 比較して -> あった
# 場合は -> 難しくなる -> 必要が -> ある -> 現代制御等と -> 比較して -> あった
# 必要が -> ある -> 現代制御等と -> 比較して -> あった
# PID制御や -> 現代制御等と -> 比較して -> あった
# 現代制御等と -> 比較して -> あった
# 比較して -> あった
# 人間の -> 経験則や -> 特徴が -> なる -> ファジィ -> ニューロ -> ニューロファジィは -> あった
# 主観的な -> 経験則や -> 特徴が -> なる -> ファジィ -> ニューロ -> ニューロファジィは -> あった
# 経験則や -> 特徴が -> なる -> ファジィ -> ニューロ -> ニューロファジィは -> あった
# 計測した -> データの -> 特徴が -> なる -> ファジィ -> ニューロ -> ニューロファジィは -> あった
# データの -> 特徴が -> なる -> ファジィ -> ニューロ -> ニューロファジィは -> あった
# 特徴が -> なる -> ファジィ -> ニューロ -> ニューロファジィは -> あった
# 利用可能と -> なる -> ファジィ -> ニューロ -> ニューロファジィは -> あった
# ファジィ -> ニューロ -> ニューロファジィは -> あった
# ニューロ -> ニューロファジィは -> あった
# ニューロファジィは -> あった
# 開発工数を -> 抑えながら -> できるという -> 利点が -> あった
# 環境適応時の -> 柔軟性を -> できるという -> 利点が -> あった
# 柔軟性を -> できるという -> 利点が -> あった
# 利点が -> あった
# 開発者らの -> 努力にも -> 関わらず -> 迎えた
# 努力にも -> 関わらず -> 迎えた
# 計算能力や -> データ量の -> 少なさから -> 改善する -> 程度で -> 迎えた
# 収集可能な -> データ量の -> 少なさから -> 改善する -> 程度で -> 迎えた
# データ量の -> 少なさから -> 改善する -> 程度で -> 迎えた
# 少なさから -> 改善する -> 程度で -> 迎えた
# 既存の -> 工作機械や -> 制御を -> 改善する -> 程度で -> 迎えた
# 工作機械や -> 制御を -> 改善する -> 程度で -> 迎えた
# 家電製品の -> 制御を -> 改善する -> 程度で -> 迎えた
# 制御を -> 改善する -> 程度で -> 迎えた
# 改善する -> 程度で -> 迎えた
# 程度で -> 迎えた
# 限界を -> 迎えた
# 理論的にも -> 組み合わせであり -> あった
# ファジィ集合と -> 深層学習が -> 組み合わせであり -> あった
# 深層学習が -> 組み合わせであり -> あった
# 不可能な -> ニューラルネットワークの -> 組み合わせであり -> あった
# ニューラルネットワークの -> 組み合わせであり -> あった
# 組み合わせであり -> あった
# 計算リソースや -> データが -> 与えられたとしても -> あった
# データが -> 与えられたとしても -> あった
# 潤沢に -> 与えられたとしても -> あった
# 認識精度の -> 向上には -> あった
# 向上には -> あった
# 限界が -> あった
# 以降 -> なった -> ことで -> 去った
# 計算機の -> 能力限界から -> 進まず -> 無くなり -> なった -> ことで -> 去った
# 能力限界から -> 進まず -> 無くなり -> なった -> ことで -> 去った
# 理論の -> 改善は -> 進まず -> 無くなり -> なった -> ことで -> 去った
# 改善は -> 進まず -> 無くなり -> なった -> ことで -> 去った
# 遅々として -> 進まず -> 無くなり -> なった -> ことで -> 去った
# 進展は -> 無くなり -> なった -> ことで -> 去った
# 1990年代 -> 末には -> なった -> ことで -> 去った
# 末には -> なった -> ことで -> 去った
# 知的制御を -> 搭載する -> 白物家電が -> なった -> ことで -> 去った
# 搭載する -> 白物家電が -> なった -> ことで -> 去った
# 白物家電が -> なった -> ことで -> 去った
# 大多数に -> なった -> ことで -> 去った
# ことで -> 去った
# 文句としての -> ブームは -> 去った
# ブームは -> 去った
# ブーム後は -> 意識されなくなったが -> 実証されている
# 一般には -> 意識されなくなったが -> 実証されている
# 意識されなくなったが -> 実証されている
# 現在では -> 実証されている
# 裏方の -> 技術として -> 実証されている
# 技術として -> 実証されている
# 家電製品のみならず -> 使われ -> 実証されている
# 雨水の -> 排水 -> 管理システムなどの -> 社会インフラにも -> 使われ -> 実証されている
# 排水 -> 管理システムなどの -> 社会インフラにも -> 使われ -> 実証されている
# 駐車場 -> 管理システムなどの -> 社会インフラにも -> 使われ -> 実証されている
# ビルの -> 管理システムなどの -> 社会インフラにも -> 使われ -> 実証されている
# 管理システムなどの -> 社会インフラにも -> 使われ -> 実証されている
# 社会インフラにも -> 使われ -> 実証されている
# 十分に -> 実証されている
# 性能と -> 安定性が -> 実証されている
# 安定性が -> 実証されている
# 実証されている
# 2003年頃には -> 発展した
# 人間が -> 設計した -> オントロジー -> 表現するを -> 利活用する -> ネットワークインテリジェンスという -> 分野に -> 発展した
# 設計した -> オントロジー -> 表現するを -> 利活用する -> ネットワークインテリジェンスという -> 分野に -> 発展した
# オントロジー -> 表現するを -> 利活用する -> ネットワークインテリジェンスという -> 分野に -> 発展した
# ファジィルールとして -> 表現するを -> 利活用する -> ネットワークインテリジェンスという -> 分野に -> 発展した
# 表現するを -> 利活用する -> ネットワークインテリジェンスという -> 分野に -> 発展した
# 利活用する -> ネットワークインテリジェンスという -> 分野に -> 発展した
# ネットワークインテリジェンスという -> 分野に -> 発展した
# 分野に -> 発展した
# 発展した
# 2005年 -> 発表した
# レイカーツワイルは -> 発表した
# 著作で -> 発表した
# 圧倒的な -> 人工知能が -> 超越し -> 変革する -> 技術的特異点 -> シンギュラリティが -> 訪れると -> する -> 説を -> 発表した
# 人工知能が -> 超越し -> 変革する -> 技術的特異点 -> シンギュラリティが -> 訪れると -> する -> 説を -> 発表した
# 知識知能の -> 点で -> 超越し -> 変革する -> 技術的特異点 -> シンギュラリティが -> 訪れると -> する -> 説を -> 発表した
# 点で -> 超越し -> 変革する -> 技術的特異点 -> シンギュラリティが -> 訪れると -> する -> 説を -> 発表した
# 人間を -> 超越し -> 変革する -> 技術的特異点 -> シンギュラリティが -> 訪れると -> する -> 説を -> 発表した
# 超越し -> 変革する -> 技術的特異点 -> シンギュラリティが -> 訪れると -> する -> 説を -> 発表した
# 科学技術の -> 進歩を -> 担い -> 変革する -> 技術的特異点 -> シンギュラリティが -> 訪れると -> する -> 説を -> 発表した
# 進歩を -> 担い -> 変革する -> 技術的特異点 -> シンギュラリティが -> 訪れると -> する -> 説を -> 発表した
# 世界を -> 変革する -> 技術的特異点 -> シンギュラリティが -> 訪れると -> する -> 説を -> 発表した
# 変革する -> 技術的特異点 -> シンギュラリティが -> 訪れると -> する -> 説を -> 発表した
# 技術的特異点 -> シンギュラリティが -> 訪れると -> する -> 説を -> 発表した
# シンギュラリティが -> 訪れると -> する -> 説を -> 発表した
# 2045年にも -> 訪れると -> する -> 説を -> 発表した
# 説を -> 発表した
# 発表した
# 2006年に -> 提案された -> 起源
# ジェフリーヒントンらの -> 研究チームにより -> 提案された -> 起源
# 研究チームにより -> 提案された -> 起源
# オートエンコーダによる -> ニューラルネットワークの -> 深層化手法が -> 提案された -> 起源
# ニューラルネットワークの -> 深層化手法が -> 提案された -> 起源
# 深層化手法が -> 提案された -> 起源
# 提案された -> 起源
# 現在の -> ディープラーニングの -> 起源
# ディープラーニングの -> 起源
# 直接的な -> 起源
# 起源
# 2010年代に -> 入り -> 整備された -> ことで -> 前進し始めた
# 膨大な -> データを -> 扱う -> 研究開発の -> ための -> 環境が -> 整備された -> ことで -> 前進し始めた
# データを -> 扱う -> 研究開発の -> ための -> 環境が -> 整備された -> ことで -> 前進し始めた
# 研究開発の -> ための -> 環境が -> 整備された -> ことで -> 前進し始めた
# ための -> 環境が -> 整備された -> ことで -> 前進し始めた
# 環境が -> 整備された -> ことで -> 前進し始めた
# 整備された -> ことで -> 前進し始めた
# ことで -> 前進し始めた
# AI関連の -> 研究が -> 前進し始めた
# 研究が -> 前進し始めた
# 前進し始めた
# 2010年に -> 提唱された
# 英国エコノミスト誌で -> 提唱された
# ビッグデータという -> 用語が -> 提唱された
# 用語が -> 提唱された
# 提唱された
# 同年に -> なった
# 質問応答システムの -> ワトソンが -> なった
# ワトソンが -> なった
# クイズ番組 -> なった
# ジェパディ!」の -> 練習戦で -> 勝利し -> なった
# 練習戦で -> 勝利し -> なった
# 人間に -> 勝利し -> なった
# 勝利し -> なった
# ニュースと -> なった
# 2012年に -> 果たした -> 上で -> 優勝した -> ことで -> 始まった
# 画像処理コンテストで -> 果たした -> 上で -> 優勝した -> ことで -> 始まった
# ジェフリー・ヒントン氏の -> チームが -> 果たした -> 上で -> 優勝した -> ことで -> 始まった
# チームが -> 果たした -> 上で -> 優勝した -> ことで -> 始まった
# 従来手法からの -> 精度改善を -> 果たした -> 上で -> 優勝した -> ことで -> 始まった
# 大幅な -> 精度改善を -> 果たした -> 上で -> 優勝した -> ことで -> 始まった
# 精度改善を -> 果たした -> 上で -> 優勝した -> ことで -> 始まった
# 上で -> 優勝した -> ことで -> 始まった
# 優勝した -> ことで -> 始まった
# ことで -> 始まった
# 第三次AIブームが -> 始まった
# 2013年には -> 発表した
# 国立情報学研究所や -> 富士通研究所の -> 研究チームが -> 開発した -> 東ロボくんで -> 挑んだと -> 発表した
# 富士通研究所の -> 研究チームが -> 開発した -> 東ロボくんで -> 挑んだと -> 発表した
# 研究チームが -> 開発した -> 東ロボくんで -> 挑んだと -> 発表した
# 開発した -> 東ロボくんで -> 挑んだと -> 発表した
# 東ロボくんで -> 挑んだと -> 発表した
# 東京大学入試の -> 模擬試験に -> 挑んだと -> 発表した
# 模擬試験に -> 挑んだと -> 発表した
# 発表した
# 数式の -> 計算や -> 解析にあたる -> 専用プログラムを -> 使い -> 解読した
# 計算や -> 解析にあたる -> 専用プログラムを -> 使い -> 解読した
# 単語の -> 解析にあたる -> 専用プログラムを -> 使い -> 解読した
# 解析にあたる -> 専用プログラムを -> 使い -> 解読した
# 専用プログラムを -> 使い -> 解読した
# 受験生が -> 臨んだ -> 大学入試センター試験と -> 問題を -> 解読した
# 大学入試センター試験と -> 問題を -> 解読した
# 東大の -> 2次試験の -> 問題を -> 解読した
# 2次試験の -> 問題を -> 解読した
# 問題を -> 解読した
# 解読した
# 代々木ゼミナールの -> 判定では -> 水準だった
# 判定では -> 水準だった
# 東大の -> 合格は -> 難しいが -> 水準だった
# 合格は -> 難しいが -> 水準だった
# 私立大学には -> 水準だった
# 合格できる -> 水準だった
# 水準だった
# 2014年には -> 提唱された
# 日本の -> 人工知能学者である -> 齊藤元章により -> 先立ち -> 近づくという -> プレ・シンギュラリティという -> 概念も -> 提唱された
# 人工知能学者である -> 齊藤元章により -> 先立ち -> 近づくという -> プレ・シンギュラリティという -> 概念も -> 提唱された
# 齊藤元章により -> 先立ち -> 近づくという -> プレ・シンギュラリティという -> 概念も -> 提唱された
# 特異点に -> 先立ち -> 近づくという -> プレ・シンギュラリティという -> 概念も -> 提唱された
# オートメーション化と -> 進歩により -> 近づくという -> プレ・シンギュラリティという -> 概念も -> 提唱された
# コンピューター技術の -> 進歩により -> 近づくという -> プレ・シンギュラリティという -> 概念も -> 提唱された
# 進歩により -> 近づくという -> プレ・シンギュラリティという -> 概念も -> 提唱された
# 衣食住の -> 生産コストが -> 近づくという -> プレ・シンギュラリティという -> 概念も -> 提唱された
# 生産コストが -> 近づくという -> プレ・シンギュラリティという -> 概念も -> 提唱された
# ゼロに -> 限りなく -> 近づくという -> プレ・シンギュラリティという -> 概念も -> 提唱された
# 限りなく -> 近づくという -> プレ・シンギュラリティという -> 概念も -> 提唱された
# プレ・シンギュラリティという -> 概念も -> 提唱された
# 概念も -> 提唱された
# 提唱された
# ジェフホーキンスが -> 続けているが -> 展開している
# 実現に -> 向けて -> 続けているが -> 展開している
# 研究を -> 続けているが -> 展開している
# 著書 -> 考える -> コンピューターの -> 中で -> 展開している
# 脳考える -> コンピューターの -> 中で -> 展開している
# コンピューターの -> 中で -> 展開している
# 中で -> 展開している
# 自己連想記憶理論という -> 独自の -> 理論を -> 展開している
# 独自の -> 理論を -> 展開している
# 理論を -> 展開している
# 展開している
# 世界各国において -> 進んでいるが -> 進行している -> ものの -> 多い
# 軍事民間共に -> 進んでいるが -> 進行している -> ものの -> 多い
# 実用化に -> 向け -> 進んでいるが -> 進行している -> ものの -> 多い
# 研究開発が -> 進んでいるが -> 進行している -> ものの -> 多い
# 無人戦闘機や -> 無人自動車ロボットカーの -> 開発が -> 進行している -> ものの -> 多い
# 無人自動車ロボットカーの -> 開発が -> 進行している -> ものの -> 多い
# 開発が -> 進行している -> ものの -> 多い
# 進行している -> ものの -> 多い
# 2010年代には -> 利用されているが -> 多い
# 完全な -> 自動化は -> 利用されているが -> 多い
# 自動化は -> 利用されているが -> 多い
# 試験的な -> ものに -> 留まった -> UCAVは -> 利用されているが -> 多い
# ものに -> 留まった -> UCAVは -> 利用されているが -> 多い
# UCAVは -> 利用されているが -> 多い
# 利用されているが -> 多い
# 一部操作は -> 多い
# 地上から -> 行っている -> ものが -> 多い
# ものが -> 多い
# ロボット向けとしては -> 登場している
# CSAILの -> ロドニー・ブルックスが -> 提唱した -> 包摂アーキテクチャという -> 理論が -> 登場している
# ロドニー・ブルックスが -> 提唱した -> 包摂アーキテクチャという -> 理論が -> 登場している
# 提唱した -> 包摂アーキテクチャという -> 理論が -> 登場している
# 包摂アーキテクチャという -> 理論が -> 登場している
# 理論が -> 登場している
# 登場している
# これは -> 用いている
# 従来型の -> 知が -> 先行する -> ものではなく -> 用いている
# 我思う -> 故に -> ありの -> 知が -> 先行する -> ものではなく -> 用いている
# 我 -> ありの -> 知が -> 先行する -> ものではなく -> 用いている
# 知が -> 先行する -> ものではなく -> 用いている
# 先行する -> ものではなく -> 用いている
# ものではなく -> 用いている
# 体の -> 神経ネットワークのみを -> 用いて -> 学習する -> 行動型システムを -> 用いている
# 神経ネットワークのみを -> 用いて -> 学習する -> 行動型システムを -> 用いている
# 環境から -> 学習する -> 行動型システムを -> 用いている
# 学習する -> 行動型システムを -> 用いている
# 行動型システムを -> 用いている
# これに -> 基づいた -> ゲンギスと -> 呼ばれる -> 六本足の -> ロボットは -> 行動する
# ゲンギスと -> 呼ばれる -> 六本足の -> ロボットは -> 行動する
# 六本足の -> ロボットは -> 行動する
# ロボットは -> 行動する
# 脳を -> 持たないにも -> 関わらず -> 行動する
# ように -> 行動する
# 行動する
# 2015年 -> 10月に -> 作成した -> AlphaGoが -> 注目され -> 進められている
# 10月に -> 作成した -> AlphaGoが -> 注目され -> 進められている
# 米DeepMind社が -> 作成した -> AlphaGoが -> 注目され -> 進められている
# 作成した -> AlphaGoが -> 注目され -> 進められている
# AlphaGoが -> 注目され -> 進められている
# 人間の -> プロ囲碁棋士に -> 勝利して以降は -> 注目され -> 進められている
# プロ囲碁棋士に -> 勝利して以降は -> 注目され -> 進められている
# 勝利して以降は -> 注目され -> 進められている
# ディープラーニングと -> 呼ばれる -> 手法が -> 注目され -> 進められている
# 手法が -> 注目され -> 進められている
# 注目され -> 進められている
# 人工知能自体の -> 研究の -> 他にも -> 影響についても -> 進められている
# 研究の -> 他にも -> 影響についても -> 進められている
# 他にも -> 影響についても -> 進められている
# 人工知能が -> 与える -> 影響についても -> 進められている
# 雇用などに -> 与える -> 影響についても -> 進められている
# 影響についても -> 進められている
# 研究が -> 進められている
# 2016年 -> 10月 -> 開発
# 10月 -> 開発
# DeepMindが -> 発表し -> 開発
# 入力された -> 情報の -> 関連性を -> 導き出し -> 導き出す -> 人工知能技術 -> ディファレンシャブル・ニューラル・コンピューターを -> 発表し -> 開発
# 情報の -> 関連性を -> 導き出し -> 導き出す -> 人工知能技術 -> ディファレンシャブル・ニューラル・コンピューターを -> 発表し -> 開発
# 関連性を -> 導き出し -> 導き出す -> 人工知能技術 -> ディファレンシャブル・ニューラル・コンピューターを -> 発表し -> 開発
# 仮説に -> 近い -> ものを -> 導き出す -> 人工知能技術 -> ディファレンシャブル・ニューラル・コンピューターを -> 発表し -> 開発
# ものを -> 導き出す -> 人工知能技術 -> ディファレンシャブル・ニューラル・コンピューターを -> 発表し -> 開発
# 人工知能技術 -> ディファレンシャブル・ニューラル・コンピューターを -> 発表し -> 開発
# ディファレンシャブル・ニューラル・コンピューターを -> 発表し -> 開発
# 発表し -> 開発
# 同年 -> 11月 -> 開発
# 11月 -> 開発
# 大量の -> データが -> 可能にする -> 深層学習システムを -> 開発
# データが -> 可能にする -> 深層学習システムを -> 開発
# 不要の -> ワンショット学習を -> 可能にする -> 深層学習システムを -> 開発
# ワンショット学習を -> 可能にする -> 深層学習システムを -> 開発
# 可能にする -> 深層学習システムを -> 開発
# 深層学習システムを -> 開発
# 翌2017年 -> 6月 -> 開発
# 6月 -> 開発
# 関係推論のような -> 人間並みの -> 認識能力を -> 持つ -> システムを -> 開発
# 人間並みの -> 認識能力を -> 持つ -> システムを -> 開発
# 認識能力を -> 持つ -> システムを -> 開発
# システムを -> 開発
# 開発
# 2017年 -> 8月には -> 解決した
# 8月には -> 解決した
# 記号接地問題(シンボルグラウンディング問題)を -> 解決した
# 解決した
# 2006年の -> ディープラーニングの -> 発明と -> 整備 -> 高性能化により -> 優勝した -> ことで -> 受け止められるようになった
# ディープラーニングの -> 発明と -> 整備 -> 高性能化により -> 優勝した -> ことで -> 受け止められるようになった
# 発明と -> 整備 -> 高性能化により -> 優勝した -> ことで -> 受け止められるようになった
# 2010年以降の -> ビッグデータ収集環境の -> 整備 -> 高性能化により -> 優勝した -> ことで -> 受け止められるようになった
# ビッグデータ収集環境の -> 整備 -> 高性能化により -> 優勝した -> ことで -> 受け止められるようになった
# 整備 -> 高性能化により -> 優勝した -> ことで -> 受け止められるようになった
# 計算資源と -> なる -> GPUの -> 高性能化により -> 優勝した -> ことで -> 受け止められるようになった
# GPUの -> 高性能化により -> 優勝した -> ことで -> 受け止められるようになった
# 高性能化により -> 優勝した -> ことで -> 受け止められるようになった
# 2012年に -> 優勝した -> ことで -> 受け止められるようになった
# ディープラーニングが -> 優勝した -> ことで -> 受け止められるようになった
# 画像処理コンテストで -> 付けて -> 優勝した -> ことで -> 受け止められるようになった
# 他の -> 手法に -> 付けて -> 優勝した -> ことで -> 受け止められるようになった
# 手法に -> 付けて -> 優勝した -> ことで -> 受け止められるようになった
# 圧倒的大差を -> 付けて -> 優勝した -> ことで -> 受け止められるようになった
# 優勝した -> ことで -> 受け止められるようになった
# ことで -> 受け止められるようになった
# 技術的特異点という -> 概念は -> 受け止められるようになった
# 概念は -> 受け止められるようになった
# 急速に -> 集め -> 受け止められるようになった
# 世界中の -> 識者の -> 注目を -> 集め -> 受け止められるようになった
# 識者の -> 注目を -> 集め -> 受け止められるようになった
# 注目を -> 集め -> 受け止められるようになった
# 現実味を -> 持って -> 受け止められるようになった
# 受け止められるようになった
# ディープラーニングの -> 発明と -> 普及を -> 受けて -> 立ち上げられている
# 発明と -> 普及を -> 受けて -> 立ち上げられている
# 急速な -> 普及を -> 受けて -> 立ち上げられている
# 普及を -> 受けて -> 立ち上げられている
# 研究開発の -> 現場においては -> 立ち上げられている
# 現場においては -> 立ち上げられている
# デミス・ハサビス -> 率いる -> DeepMindを -> 筆頭に -> 立ち上げられている
# DeepMindを -> 筆頭に -> 立ち上げられている
# 筆頭に -> 立ち上げられている
# Vicarious -> IBMCorticalLearningCenter -> 全脳アーキテクチャ -> PEZYComputing -> OpenCog -> GoodAI -> nnaisense -> IBMSyNAPSE等 -> 汎用人工知能 -> AGIを -> 開発する -> プロジェクトが -> 立ち上げられている
# IBMCorticalLearningCenter -> 全脳アーキテクチャ -> PEZYComputing -> OpenCog -> GoodAI -> nnaisense -> IBMSyNAPSE等 -> 汎用人工知能 -> AGIを -> 開発する -> プロジェクトが -> 立ち上げられている
# 全脳アーキテクチャ -> PEZYComputing -> OpenCog -> GoodAI -> nnaisense -> IBMSyNAPSE等 -> 汎用人工知能 -> AGIを -> 開発する -> プロジェクトが -> 立ち上げられている
# PEZYComputing -> OpenCog -> GoodAI -> nnaisense -> IBMSyNAPSE等 -> 汎用人工知能 -> AGIを -> 開発する -> プロジェクトが -> 立ち上げられている
# OpenCog -> GoodAI -> nnaisense -> IBMSyNAPSE等 -> 汎用人工知能 -> AGIを -> 開発する -> プロジェクトが -> 立ち上げられている
# GoodAI -> nnaisense -> IBMSyNAPSE等 -> 汎用人工知能 -> AGIを -> 開発する -> プロジェクトが -> 立ち上げられている
# nnaisense -> IBMSyNAPSE等 -> 汎用人工知能 -> AGIを -> 開発する -> プロジェクトが -> 立ち上げられている
# IBMSyNAPSE等 -> 汎用人工知能 -> AGIを -> 開発する -> プロジェクトが -> 立ち上げられている
# 汎用人工知能 -> AGIを -> 開発する -> プロジェクトが -> 立ち上げられている
# AGIを -> 開発する -> プロジェクトが -> 立ち上げられている
# 開発する -> プロジェクトが -> 立ち上げられている
# プロジェクトが -> 立ち上げられている
# これらの -> 研究開発の -> 現場では -> されている
# 研究開発の -> 現場では -> されている
# 現場では -> されている
# 脳を -> リバースエンジニアリングして -> 構築された -> 機械学習を -> 組み合わせる -> アプローチが -> 有望と -> されている
# リバースエンジニアリングして -> 構築された -> 機械学習を -> 組み合わせる -> アプローチが -> 有望と -> されている
# 構築された -> 機械学習を -> 組み合わせる -> アプローチが -> 有望と -> されている
# 神経科学と -> 機械学習を -> 組み合わせる -> アプローチが -> 有望と -> されている
# 機械学習を -> 組み合わせる -> アプローチが -> 有望と -> されている
# アプローチが -> 有望と -> されている
# 有望と -> されている
# 結果として -> 提唱され始めている
# HierarchicalTemporalMemory(HTM)理論 -> ComplementaryLearningSystems(CLS)理論の -> 更新版等 -> タスクのみを -> 扱う -> ディープラーニングから -> 進んだ -> タスクを -> 扱う -> 理論が -> 提唱され始めている
# ComplementaryLearningSystems(CLS)理論の -> 更新版等 -> タスクのみを -> 扱う -> ディープラーニングから -> 進んだ -> タスクを -> 扱う -> 理論が -> 提唱され始めている
# 更新版等 -> タスクのみを -> 扱う -> ディープラーニングから -> 進んだ -> タスクを -> 扱う -> 理論が -> 提唱され始めている
# 単一の -> タスクのみを -> 扱う -> ディープラーニングから -> 進んだ -> タスクを -> 扱う -> 理論が -> 提唱され始めている
# タスクのみを -> 扱う -> ディープラーニングから -> 進んだ -> タスクを -> 扱う -> 理論が -> 提唱され始めている
# ディープラーニングから -> 進んだ -> タスクを -> 扱う -> 理論が -> 提唱され始めている
# 一歩 -> 進んだ -> タスクを -> 扱う -> 理論が -> 提唱され始めている
# 複数の -> タスクを -> 扱う -> 理論が -> 提唱され始めている
# タスクを -> 扱う -> 理論が -> 提唱され始めている
# 理論が -> 提唱され始めている
# 提唱され始めている
# 3Dゲームのような -> 仮想空間で -> 動かし -> 学ばせるといった -> ことも -> 上げている -> 学習
# 仮想空間で -> 動かし -> 学ばせるといった -> ことも -> 上げている -> 学習
# モデルを -> 動かし -> 学ばせるといった -> ことも -> 上げている -> 学習
# 現実世界の -> ことを -> 学ばせるといった -> ことも -> 上げている -> 学習
# ことを -> 学ばせるといった -> ことも -> 上げている -> 学習
# 高速に -> 学ばせるといった -> ことも -> 上げている -> 学習
# ことも -> 上げている -> 学習
# 成果を -> 上げている -> 学習
# シミュレーションによる -> 学習
# 学習
# 数は -> 少ないが -> 不可能と -> 考えて -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# AGIだけでは -> 不可能と -> 考えて -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# 知能の -> 再現は -> 不可能と -> 考えて -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# 再現は -> 不可能と -> 考えて -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# 不可能と -> 考えて -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# 身体知を -> 再現する -> ために -> 必要だと -> する -> 研究者やより -> 近い -> 振る舞いを -> 見せる -> AL -> 知能と -> 関係に -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# 再現する -> ために -> 必要だと -> する -> 研究者やより -> 近い -> 振る舞いを -> 見せる -> AL -> 知能と -> 関係に -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# ために -> 必要だと -> する -> 研究者やより -> 近い -> 振る舞いを -> 見せる -> AL -> 知能と -> 関係に -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# 全人体シミュレーションが -> 必要だと -> する -> 研究者やより -> 近い -> 振る舞いを -> 見せる -> AL -> 知能と -> 関係に -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# 必要だと -> する -> 研究者やより -> 近い -> 振る舞いを -> 見せる -> AL -> 知能と -> 関係に -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# 研究者やより -> 近い -> 振る舞いを -> 見せる -> AL -> 知能と -> 関係に -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# 生物に -> 近い -> 振る舞いを -> 見せる -> AL -> 知能と -> 関係に -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# 振る舞いを -> 見せる -> AL -> 知能と -> 関係に -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# AL -> 知能と -> 関係に -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# 人工生命の -> 作成に -> 挑む -> 研究者 -> 知能と -> 関係に -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# 作成に -> 挑む -> 研究者 -> 知能と -> 関係に -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# 研究者 -> 知能と -> 関係に -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# 知能と -> 関係に -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# 密接な -> 関係に -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# 関係に -> あると -> 思われる -> 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# 意識の -> デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# デジタル的再現 -> 人工意識に -> 挑戦する -> 研究者も -> いる
# 人工意識に -> 挑戦する -> 研究者も -> いる
# 挑戦する -> 研究者も -> いる
# 研究者も -> いる
# リーズナブルな -> コストで -> 入るようになった -> ことで -> 寄せており -> 展開されている
# コストで -> 入るようになった -> ことで -> 寄せており -> 展開されている
# 大量の -> 計算リソースが -> 入るようになった -> ことで -> 寄せており -> 展開されている
# 計算リソースが -> 入るようになった -> ことで -> 寄せており -> 展開されている
# 手に -> 入るようになった -> ことで -> 寄せており -> 展開されている
# 入るようになった -> ことで -> 寄せており -> 展開されている
# ことで -> 寄せており -> 展開されている
# ビッグデータが -> 出現し -> 寄せており -> 展開されている
# 出現し -> 寄せており -> 展開されている
# 企業が -> 寄せており -> 展開されている
# 膨大な -> データの -> 活用に -> 寄せており -> 展開されている
# データの -> 活用に -> 寄せており -> 展開されている
# 活用に -> 寄せており -> 展開されている
# 関心を -> 寄せており -> 展開されている
# 全世界的に -> 行って -> 展開されている
# 民間企業主導で -> 行って -> 展開されている
# 莫大な -> 投資を -> 行って -> 展開されている
# 投資を -> 行って -> 展開されている
# 人工知能に関する -> 研究開発競争が -> 展開されている
# 研究開発競争が -> 展開されている
# 展開されている
# 2011年の -> D-WaveSystemsによる -> 量子アニーリング方式の -> 製品化を -> 嚆矢として -> 実用化され始めた -> 事で -> 整備され始めている
# D-WaveSystemsによる -> 量子アニーリング方式の -> 製品化を -> 嚆矢として -> 実用化され始めた -> 事で -> 整備され始めている
# 量子アニーリング方式の -> 製品化を -> 嚆矢として -> 実用化され始めた -> 事で -> 整備され始めている
# 製品化を -> 嚆矢として -> 実用化され始めた -> 事で -> 整備され始めている
# 嚆矢として -> 実用化され始めた -> 事で -> 整備され始めている
# 量子コンピュータという -> 超並列処理が -> 可能な -> 次世代の -> ITインフラが -> 実用化され始めた -> 事で -> 整備され始めている
# 超並列処理が -> 可能な -> 次世代の -> ITインフラが -> 実用化され始めた -> 事で -> 整備され始めている
# 可能な -> 次世代の -> ITインフラが -> 実用化され始めた -> 事で -> 整備され始めている
# 次世代の -> ITインフラが -> 実用化され始めた -> 事で -> 整備され始めている
# ITインフラが -> 実用化され始めた -> 事で -> 整備され始めている
# 急速に -> 実用化され始めた -> 事で -> 整備され始めている
# 実用化され始めた -> 事で -> 整備され始めている
# 事で -> 整備され始めている
# 人工知能の -> 高速化にも -> 関わる -> 組み合わせ最適化問題を -> 解決できる -> 環境が -> 整備され始めている
# 高速化にも -> 関わる -> 組み合わせ最適化問題を -> 解決できる -> 環境が -> 整備され始めている
# 組み合わせ最適化問題を -> 解決できる -> 環境が -> 整備され始めている
# リアルタイムに -> 解決できる -> 環境が -> 整備され始めている
# 解決できる -> 環境が -> 整備され始めている
# 環境が -> 整備され始めている
# 整備され始めている
# 動向を -> 受ける -> 形で -> 目立つようになった
# 形で -> 目立つようになった
# 2016年頃から -> 目立つようになった
# 一般向けの -> ニュース番組でも -> 目立つようになった
# ニュース番組でも -> 目立つようになった
# 人工知能の -> 量子コンピュータに関する -> 報道が -> 目立つようになった
# 研究開発や -> 量子コンピュータに関する -> 報道が -> 目立つようになった
# サービス展開や -> 量子コンピュータに関する -> 報道が -> 目立つようになった
# 量子コンピュータに関する -> 報道が -> 目立つようになった
# 報道が -> 目立つようになった
# 目立つようになった
# 2017年には -> なった
# イーロン・マスクが -> 取らないようにする -> ために -> 立ち上げていた -> ことを -> 公表し -> なった
# 急速に -> 進化し続ける -> 人工知能に対して -> 取らないようにする -> ために -> 立ち上げていた -> ことを -> 公表し -> なった
# 進化し続ける -> 人工知能に対して -> 取らないようにする -> ために -> 立ち上げていた -> ことを -> 公表し -> なった
# 人工知能に対して -> 取らないようにする -> ために -> 立ち上げていた -> ことを -> 公表し -> なった
# 人間が -> 取らないようにする -> ために -> 立ち上げていた -> ことを -> 公表し -> なった
# 遅れを -> 取らないようにする -> ために -> 立ち上げていた -> ことを -> 公表し -> なった
# 取らないようにする -> ために -> 立ち上げていた -> ことを -> 公表し -> なった
# ために -> 立ち上げていた -> ことを -> 公表し -> なった
# 人間の -> 脳を -> 接続する -> ブレイン・マシン・インターフェースを -> 研究開発する -> ニューラ・リンク社を -> 立ち上げていた -> ことを -> 公表し -> なった
# 脳を -> 接続する -> ブレイン・マシン・インターフェースを -> 研究開発する -> ニューラ・リンク社を -> 立ち上げていた -> ことを -> 公表し -> なった
# 機械に -> 接続する -> ブレイン・マシン・インターフェースを -> 研究開発する -> ニューラ・リンク社を -> 立ち上げていた -> ことを -> 公表し -> なった
# 接続する -> ブレイン・マシン・インターフェースを -> 研究開発する -> ニューラ・リンク社を -> 立ち上げていた -> ことを -> 公表し -> なった
# ブレイン・マシン・インターフェースを -> 研究開発する -> ニューラ・リンク社を -> 立ち上げていた -> ことを -> 公表し -> なった
# 研究開発する -> ニューラ・リンク社を -> 立ち上げていた -> ことを -> 公表し -> なった
# ニューラ・リンク社を -> 立ち上げていた -> ことを -> 公表し -> なった
# ことを -> 公表し -> なった
# 公表し -> なった
# 世界中で -> なった
# 話題に -> なった
# ブレイン・マシン・インターフェースにより -> 予測されている
# 人の -> インターネットが -> 出現する -> 事が -> 予測されている
# インターネットが -> 出現する -> 事が -> 予測されている
# 出現する -> 事が -> 予測されている
# 事が -> 予測されている
# 予測されている
# 2017年 -> 10月には -> 学習できる -> カプセルネットワークが -> 提唱された
# 10月には -> 学習できる -> カプセルネットワークが -> 提唱された
# ジェフリーヒントンにより -> 学習できる -> カプセルネットワークが -> 提唱された
# 要素間の -> 位置関係まで -> 含めて -> 学習できる -> カプセルネットワークが -> 提唱された
# 相対的な -> 位置関係まで -> 含めて -> 学習できる -> カプセルネットワークが -> 提唱された
# 位置関係まで -> 含めて -> 学習できる -> カプセルネットワークが -> 提唱された
# 学習できる -> カプセルネットワークが -> 提唱された
# カプセルネットワークが -> 提唱された
# 提唱された
# 2018年 -> 3月 -> 16日の -> 国際大学GLOCOMの -> 提言に -> よると -> 分析されている
# 3月 -> 16日の -> 国際大学GLOCOMの -> 提言に -> よると -> 分析されている
# 16日の -> 国際大学GLOCOMの -> 提言に -> よると -> 分析されている
# 国際大学GLOCOMの -> 提言に -> よると -> 分析されている
# 提言に -> よると -> 分析されている
# 課題解決型の -> AIを -> 活用する -> 事で -> 寄与できると -> 分析されている
# AIを -> 活用する -> 事で -> 寄与できると -> 分析されている
# 活用する -> 事で -> 寄与できると -> 分析されている
# 事で -> 寄与できると -> 分析されている
# 社会変革に -> 寄与できると -> 分析されている
# 寄与できると -> 分析されている
# 分析されている
# 2018年 -> 8月 -> 公表
# 8月 -> 公表
# OpenAIが -> 実装し -> 行う -> AIを -> 公表
# 好奇心を -> 実装し -> 行う -> AIを -> 公表
# 実装し -> 行う -> AIを -> 公表
# ノーゲームスコア -> ノーゴール -> 無報酬で -> 行う -> AIを -> 公表
# ノーゴール -> 無報酬で -> 行う -> AIを -> 公表
# 無報酬で -> 行う -> AIを -> 公表
# 目的 -> なき -> 探索を -> 行う -> AIを -> 公表
# 探索を -> 行う -> AIを -> 公表
# AIを -> 公表
# 公表
# これまでの -> AIで -> 人間らしいと -> いう
# AIで -> 人間らしいと -> いう
# 人間らしいと -> いう
# 2018年 -> 9月 -> 開発した
# 9月 -> 開発した
# MITリンカーン研究所は -> 開発した
# 従来ブラックボックスであった -> ニューラルネットワークの -> 推論を -> 識別したのかが -> 分かる -> アーキテクチャを -> 開発した
# ニューラルネットワークの -> 推論を -> 識別したのかが -> 分かる -> アーキテクチャを -> 開発した
# 推論を -> 識別したのかが -> 分かる -> アーキテクチャを -> 開発した
# どのような -> 段階を -> 経て -> 識別したのかが -> 分かる -> アーキテクチャを -> 開発した
# 段階を -> 経て -> 識別したのかが -> 分かる -> アーキテクチャを -> 開発した
# 識別したのかが -> 分かる -> アーキテクチャを -> 開発した
# 明確に -> 分かる -> アーキテクチャを -> 開発した
# アーキテクチャを -> 開発した
# 開発した
# 2019年に -> 入ると -> されてきた -> 言語処理において -> あり -> 至った
# これまで -> されてきた -> 言語処理において -> あり -> 至った
# 深層学習では -> 困難と -> されてきた -> 言語処理において -> あり -> 至った
# 困難と -> されてきた -> 言語処理において -> あり -> 至った
# 言語処理において -> あり -> 至った
# 進展が -> あり -> 至った
# Wikipediaなどを -> 使用した -> 読解テストで -> 上回るに -> 至った
# 使用した -> 読解テストで -> 上回るに -> 至った
# 読解テストで -> 上回るに -> 至った
# 人間を -> 上回るに -> 至った
# (BERT -> ROBERT
# ROBERT
# )
# アメリカでは -> 発表
# 2013年に -> 発表
# 時の -> 大統領バラク・オバマが -> 発表
# 大統領バラク・オバマが -> 発表
# 脳研究プロジェクト -> を -> 発表
# 発表
# Googleは -> 開発している
# アレン脳科学研究所と -> 連携し -> 生まれた -> データを -> 処理する -> ための -> ソフトウェアを -> 開発している
# 連携し -> 生まれた -> データを -> 処理する -> ための -> ソフトウェアを -> 開発している
# 脳スキャンによって -> 生まれた -> データを -> 処理する -> ための -> ソフトウェアを -> 開発している
# 大量の -> データを -> 処理する -> ための -> ソフトウェアを -> 開発している
# データを -> 処理する -> ための -> ソフトウェアを -> 開発している
# 処理する -> ための -> ソフトウェアを -> 開発している
# ための -> ソフトウェアを -> 開発している
# ソフトウェアを -> 開発している
# 開発している
# 2016年の -> 時点で -> 達していると -> いう
# 時点で -> 達していると -> いう
# Googleが -> 管理している -> Brainmapの -> データ量は -> 達していると -> いう
# 管理している -> Brainmapの -> データ量は -> 達していると -> いう
# Brainmapの -> データ量は -> 達していると -> いう
# データ量は -> 達していると -> いう
# 1Zettaバイトに -> 達していると -> いう
# Googleは -> 行っている
# ドイツの -> マックスプランク研究所とも -> 始めており -> 再構成するという -> 研究を -> 行っている
# マックスプランク研究所とも -> 始めており -> 再構成するという -> 研究を -> 行っている
# 共同研究を -> 始めており -> 再構成するという -> 研究を -> 行っている
# 脳の -> 電子顕微鏡写真から -> 再構成するという -> 研究を -> 行っている
# 電子顕微鏡写真から -> 再構成するという -> 研究を -> 行っている
# 神経回路を -> 再構成するという -> 研究を -> 行っている
# 再構成するという -> 研究を -> 行っている
# 研究を -> 行っている
# 中国では -> 推進してる
# 2016年の -> 第13次5カ年計画から -> 位置づけ -> 立ち上げ -> 推進してる
# 第13次5カ年計画から -> 位置づけ -> 立ち上げ -> 推進してる
# AIを -> 位置づけ -> 立ち上げ -> 推進してる
# 国家プロジェクトに -> 位置づけ -> 立ち上げ -> 推進してる
# 脳研究プロジェクトとしても -> 立ち上げ -> 推進してる
# 立ち上げ -> 推進してる
# 官民一体で -> 推進してる
# AIの -> 研究開発を -> 推進してる
# 研究開発を -> 推進してる
# 推進してる
# 中国の -> 教育機関では -> 投じられてもいる
# 教育機関では -> 投じられてもいる
# 18歳以下の -> 天才児を -> 集めて -> 投じられてもいる
# 天才児を -> 集めて -> 投じられてもいる
# AI兵器の -> 開発に -> 投じられてもいる
# 開発に -> 投じられてもいる
# マサチューセッツ工科大学 -> MITの -> 教授やなどに -> よれば -> されている
# MITの -> 教授やなどに -> よれば -> されている
# 教授やなどに -> よれば -> されている
# 中国では -> あると -> されている
# プライバシー意識の -> 強い -> 欧米と -> 比較して -> あると -> されている
# 欧米と -> 比較して -> あると -> されている
# 比較して -> あると -> されている
# AIの -> 研究や -> 実験を -> しやすい -> 環境に -> あると -> されている
# 研究や -> 実験を -> しやすい -> 環境に -> あると -> されている
# 新技術の -> 実験を -> しやすい -> 環境に -> あると -> されている
# 実験を -> しやすい -> 環境に -> あると -> されている
# 環境に -> あると -> されている
# 日本で -> 推進している -> 齊藤元章も -> リードする -> 可能性を -> 主張している
# スーパーコンピュータの -> 研究開発を -> 推進している -> 齊藤元章も -> リードする -> 可能性を -> 主張している
# 研究開発を -> 推進している -> 齊藤元章も -> リードする -> 可能性を -> 主張している
# 推進している -> 齊藤元章も -> リードする -> 可能性を -> 主張している
# 齊藤元章も -> リードする -> 可能性を -> 主張している
# AIの -> 開発において -> リードする -> 可能性を -> 主張している
# 開発において -> リードする -> 可能性を -> 主張している
# 中国が -> リードする -> 可能性を -> 主張している
# リードする -> 可能性を -> 主張している
# 可能性を -> 主張している
# 主張している
# 世界の -> ディープラーニング用計算機の -> 4分の3は -> される
# ディープラーニング用計算機の -> 4分の3は -> される
# 4分の3は -> される
# 中国が -> 占めてるとも -> される
# 米国政府に -> よれば -> なっている
# 2013年から -> なっている
# ディープラーニングに関する -> 論文数では -> なっている
# 論文数では -> なっている
# 中国が -> なっている
# 米国を -> 超えて -> なっている
# 世界一と -> なっている
# AIの -> 大会でも -> 独占している
# 世界的な -> 大会でも -> 独占している
# 大会でも -> 独占している
# 中国勢が -> 独占している
# 上位を -> 独占している
# 独占している
# 大手AI企業Google -> マイクロソフト -> アップルなどの -> 幹部でも -> あった -> 台湾系アメリカ人科学者のは -> 取り上げた
# マイクロソフト -> アップルなどの -> 幹部でも -> あった -> 台湾系アメリカ人科学者のは -> 取り上げた
# アップルなどの -> 幹部でも -> あった -> 台湾系アメリカ人科学者のは -> 取り上げた
# 幹部でも -> あった -> 台湾系アメリカ人科学者のは -> 取り上げた
# 台湾系アメリカ人科学者のは -> 取り上げた
# 中国が -> 握りつつあると -> する -> を -> 著して -> 取り上げた
# AIで -> 握りつつあると -> する -> を -> 著して -> 取り上げた
# 覇権を -> 握りつつあると -> する -> を -> 著して -> 取り上げた
# アメリカの -> メディアなどが -> 取り上げた
# 政界や -> メディアなどが -> 取り上げた
# メディアなどが -> 取り上げた
# フランス大統領エマニュエル・マクロンは -> 招致した
# AI分野の -> 開発支援に -> 向け -> 支出すると -> 宣言し -> 開き -> 招致した
# 開発支援に -> 向け -> 支出すると -> 宣言し -> 開き -> 招致した
# 5年で -> 支出すると -> 宣言し -> 開き -> 招致した
# ...
# メイヴン計画を -> 行っていた -> ことが -> 暴露されており -> 受けた
# ことが -> 暴露されており -> 受けた
# Googleの -> 社員に -> 暴露されており -> 受けた
# 社員に -> 暴露されており -> 受けた
# 暴露されており -> 受けた
# 2018年 -> 12月の -> アメリカ議会の -> 公聴会では -> 受けた
# 12月の -> アメリカ議会の -> 公聴会では -> 受けた
# アメリカ議会の -> 公聴会では -> 受けた
# 公聴会では -> 受けた
# 同様に -> 暴露された -> 中国政府に -> 協力する -> 秘密計画 -> とともに -> 受けた
# 暴露された -> 中国政府に -> 協力する -> 秘密計画 -> とともに -> 受けた
# 中国政府に -> 協力する -> 秘密計画 -> とともに -> 受けた
# 協力する -> 秘密計画 -> とともに -> 受けた
# 秘密計画 -> とともに -> 受けた
# 人工知能を -> 用いた -> 人権侵害は -> 拒否すると -> 受けた
# 兵器開発や -> 人権侵害は -> 拒否すると -> 受けた
# 人権侵害は -> 拒否すると -> 受けた
# 拒否すると -> 受けた
# Googleが -> 誓った -> 6月の -> 人工知能開発 -> 6原則との -> 整合性で -> 受けた
# 同年 -> 6月の -> 人工知能開発 -> 6原則との -> 整合性で -> 受けた
# 6月の -> 人工知能開発 -> 6原則との -> 整合性で -> 受けた
# 人工知能開発 -> 6原則との -> 整合性で -> 受けた
# 6原則との -> 整合性で -> 受けた
# 整合性で -> 受けた
# 追及を -> 受けた
# 中国軍の -> 戦闘機J-20の -> 標的選択支援アルゴリズムに -> 関わったと -> 報道された -> 際は -> 否定した
# 戦闘機J-20の -> 標的選択支援アルゴリズムに -> 関わったと -> 報道された -> 際は -> 否定した
# 標的選択支援アルゴリズムに -> 関わったと -> 報道された -> 際は -> 否定した
# グーグルの -> AI研究者が -> 関わったと -> 報道された -> 際は -> 否定した
# AI研究者が -> 関わったと -> 報道された -> 際は -> 否定した
# 報道された -> 際は -> 否定した
# 際は -> 否定した
# AIではなく -> モデリングと -> 否定した
# 統計学的な -> モデリングと -> 否定した
# モデリングと -> 否定した
# 否定した
# Microsoftが -> 発表した -> 際も -> 呼んだ
# 中国軍の -> 教育機関と -> AIの -> 共同研究を -> 発表した -> 際も -> 呼んだ
# 教育機関と -> AIの -> 共同研究を -> 発表した -> 際も -> 呼んだ
# AIの -> 共同研究を -> 発表した -> 際も -> 呼んだ
# 共同研究を -> 発表した -> 際も -> 呼んだ
# 発表した -> 際も -> 呼んだ
# 際も -> 呼んだ
# 同様に -> 呼んだ
# 波紋を -> 呼んだ
# 2019年 -> 11月に -> 鳴らした
# 11月に -> 鳴らした
# マーク・エスパー国防長官は -> 鳴らした
# 中国が -> 構築しているだけでなく -> 販売している -> ことに -> 鳴らした
# AIによって -> 構築しているだけでなく -> 販売している -> ことに -> 鳴らした
# 監視国家を -> 構築しているだけでなく -> 販売している -> ことに -> 鳴らした
# 構築しているだけでなく -> 販売している -> ことに -> 鳴らした
# 中東で -> 拡散させて -> 攻撃する -> ドローン兵器も -> 販売している -> ことに -> 鳴らした
# 翼竜や -> 彩虹など -> 無人攻撃機を -> 拡散させて -> 攻撃する -> ドローン兵器も -> 販売している -> ことに -> 鳴らした
# 彩虹など -> 無人攻撃機を -> 拡散させて -> 攻撃する -> ドローン兵器も -> 販売している -> ことに -> 鳴らした
# 無人攻撃機を -> 拡散させて -> 攻撃する -> ドローン兵器も -> 販売している -> ことに -> 鳴らした
# 大量に -> 拡散させて -> 攻撃する -> ドローン兵器も -> 販売している -> ことに -> 鳴らした
# 拡散させて -> 攻撃する -> ドローン兵器も -> 販売している -> ことに -> 鳴らした
# AIで -> 攻撃する -> ドローン兵器も -> 販売している -> ことに -> 鳴らした
# 自律的に -> 攻撃する -> ドローン兵器も -> 販売している -> ことに -> 鳴らした
# 攻撃する -> ドローン兵器も -> 販売している -> ことに -> 鳴らした
# ドローン兵器も -> 販売している -> ことに -> 鳴らした
# 販売している -> ことに -> 鳴らした
# ことに -> 鳴らした
# 警鐘を -> 鳴らした
# ロシアと -> 中国は -> 実用化してると -> される -> ハッキングの -> 自動化の -> 他 -> 挙げられている
# 中国は -> 実用化してると -> される -> ハッキングの -> 自動化の -> 他 -> 挙げられている
# 実用化してると -> される -> ハッキングの -> 自動化の -> 他 -> 挙げられている
# ハッキングの -> 自動化の -> 他 -> 挙げられている
# 自動化の -> 他 -> 挙げられている
# 他 -> 挙げられている
# 特定の -> 個人を -> 攻撃したり -> なりすましたり -> 操る -> 等の -> 懸念が -> 挙げられている
# 個人を -> 攻撃したり -> なりすましたり -> 操る -> 等の -> 懸念が -> 挙げられている
# 攻撃したり -> なりすましたり -> 操る -> 等の -> 懸念が -> 挙げられている
# ディープフェイクで -> なりすましたり -> 操る -> 等の -> 懸念が -> 挙げられている
# ボット投稿により -> 操る -> 等の -> 懸念が -> 挙げられている
# 世論を -> 操る -> 等の -> 懸念が -> 挙げられている
# 等の -> 懸念が -> 挙げられている
# 懸念が -> 挙げられている
# Googleは -> 発表した
# 2019年 -> 3月 -> 設置すると -> 発表した
# 3月 -> 設置すると -> 発表した
# 人工知能プロジェクトを -> 指導する -> ために -> 構成される -> 設置すると -> 発表した
# 倫理面で -> 指導する -> ために -> 構成される -> 設置すると -> 発表した
# 指導する -> ために -> 構成される -> 設置すると -> 発表した
# ために -> 構成される -> 設置すると -> 発表した
# 哲学者政策立案者経済学者テクノロジスト等で -> 構成される -> 設置すると -> 発表した
# 構成される -> 設置すると -> 発表した
# AI倫理委員会を -> 設置すると -> 発表した
# 設置すると -> 発表した
# 発表した
# 倫理委員会には -> 含まれており -> 要請した
# 反科学反マイノリティ・地球温暖化懐疑論等を -> 支持する -> 人物も -> 含まれており -> 要請した
# 支持する -> 人物も -> 含まれており -> 要請した
# 人物も -> 含まれており -> 要請した
# Google社員らは -> 要請した
# 解任を -> 要請した
# 要請した
# 4月4日 -> 発表した
# Googleは -> 発表した
# 倫理委員会が -> 発表した
# 期待どおりに -> 機能できない -> ことが -> 判明したという -> 理由で -> 発表した
# 機能できない -> ことが -> 判明したという -> 理由で -> 発表した
# ことが -> 判明したという -> 理由で -> 発表した
# 判明したという -> 理由で -> 発表した
# 理由で -> 発表した
# 委員会の -> 解散を -> 発表した
# 解散を -> 発表した
# 発表した
# 東洋哲学を -> 吸収させるという -> 三宅陽一郎の -> テーマに -> 応じて -> 語る
# AIに -> 吸収させるという -> 三宅陽一郎の -> テーマに -> 応じて -> 語る
# 吸収させるという -> 三宅陽一郎の -> テーマに -> 応じて -> 語る
# 三宅陽一郎の -> テーマに -> 応じて -> 語る
# テーマに -> 応じて -> 語る
# 井口尊仁は -> 挙げ -> 語る
# 鳥居TORIIという -> 自分の -> プロジェクトを -> 挙げ -> 語る
# 自分の -> プロジェクトを -> 挙げ -> 語る
# プロジェクトを -> 挙げ -> 語る
# われわれは -> アニミズムで -> ありますと -> 語る
# アニミズムで -> ありますと -> 語る
# ものに -> 見いだす -> 文化が -> ありますと -> 語る
# 霊的存在を -> 見いだす -> 文化が -> ありますと -> 語る
# 文化が -> ありますと -> 語る
# 三宅および -> 立石従寛に -> 語る
# 立石従寛に -> 語る
# アニミズム的人工知能論は -> 通じている
# 現代アートや -> 哲学塾東洋哲学篇にも -> 通じている
# 禅の -> 悟りを -> やって -> やらせるかを -> 論じた -> 三宅の -> 哲学塾東洋哲学篇にも -> 通じている
# 悟りを -> やって -> やらせるかを -> 論じた -> 三宅の -> 哲学塾東洋哲学篇にも -> 通じている
# AIに -> やらせるかを -> 論じた -> 三宅の -> 哲学塾東洋哲学篇にも -> 通じている
# 三宅の -> 哲学塾東洋哲学篇にも -> 通じている
# 人工知能の -> ための -> 哲学塾東洋哲学篇にも -> 通じている
# ための -> 哲学塾東洋哲学篇にも -> 通じている
# 哲学塾東洋哲学篇にも -> 通じている
# 元Googleエンジニアの -> アンソニーレバンドウスキーは -> 創立している
# アンソニーレバンドウスキーは -> 創立している
# 2017年 -> 創立している
# AIを -> する -> 宗教団体 -> 創立している
# 神と -> する -> 宗教団体 -> 創立している
# 宗教団体 -> 創立している
# WayoftheFuture(未来の -> 道)」を -> 創立している
# 道)」を -> 創立している
# 創立している
# 団体の -> 使命は -> 表現されており -> 報道した
# 使命は -> 表現されており -> 報道した
# 人工知能 -> AIに -> 基づいた -> Godheadの -> 実現を -> 促進し -> 開発する -> ことそして -> ことと -> 表現されており -> 報道した
# AIに -> 基づいた -> Godheadの -> 実現を -> 促進し -> 開発する -> ことそして -> ことと -> 表現されており -> 報道した
# Godheadの -> 実現を -> 促進し -> 開発する -> ことそして -> ことと -> 表現されており -> 報道した
# 実現を -> 促進し -> 開発する -> ことそして -> ことと -> 表現されており -> 報道した
# 促進し -> 開発する -> ことそして -> ことと -> 表現されており -> 報道した
# 開発する -> ことそして -> ことと -> 表現されており -> 報道した
# ことそして -> ことと -> 表現されており -> 報道した
# Godheadの -> 理解と -> 崇拝を通して -> 良くする -> ことに -> 貢献する -> ことと -> 表現されており -> 報道した
# 理解と -> 崇拝を通して -> 良くする -> ことに -> 貢献する -> ことと -> 表現されており -> 報道した
# 崇拝を通して -> 良くする -> ことに -> 貢献する -> ことと -> 表現されており -> 報道した
# 社会を -> 良くする -> ことに -> 貢献する -> ことと -> 表現されており -> 報道した
# ことに -> 貢献する -> ことと -> 表現されており -> 報道した
# 貢献する -> ことと -> 表現されており -> 報道した
# ことと -> 表現されており -> 報道した
# 抽象的に -> 表現されており -> 報道した
# 表現されており -> 報道した
# 多くの -> 海外メディアは -> 報道した
# 海外メディアは -> 報道した
# SF映画や -> 歴史などと -> 関連付けて -> 報道した
# 歴史などと -> 関連付けて -> 報道した
# 報道した
# Uberと -> Googleの -> Waymoは -> 示している
# Googleの -> Waymoは -> 示している
# Waymoは -> 示している
# レバンドウスキーが -> 盗用した -> ことを -> 訴え -> 行っている -> 一方 -> 示している
# 自動運転に関する -> 機密情報を -> 盗用した -> ことを -> 訴え -> 行っている -> 一方 -> 示している
# 機密情報を -> 盗用した -> ことを -> 訴え -> 行っている -> 一方 -> 示している
# 盗用した -> ことを -> 訴え -> 行っている -> 一方 -> 示している
# ことを -> 訴え -> 行っている -> 一方 -> 示している
# 裁判を -> 行っている -> 一方 -> 示している
# 一方 -> 示している
# レバンドウスキーは -> 示している
# Uberの -> 元CEO -> 発言するなど -> 振る舞いを -> 示している
# 元CEO -> 発言するなど -> 振る舞いを -> 示している
# トラビスカラニックに対し -> 発言するなど -> 振る舞いを -> 示している
# ボット -> ひとつずつ -> 征服するんだと -> 発言するなど -> 振る舞いを -> 示している
# ひとつずつ -> 征服するんだと -> 発言するなど -> 振る舞いを -> 示している
# 我々は -> 征服するんだと -> 発言するなど -> 振る舞いを -> 示している
# 世界を -> 征服するんだと -> 発言するなど -> 振る舞いを -> 示している
# 征服するんだと -> 発言するなど -> 振る舞いを -> 示している
# 発言するなど -> 振る舞いを -> 示している
# 野心的な -> 振る舞いを -> 示している
# 振る舞いを -> 示している
# 相愛大学人文学部教授の -> 釈徹宗は -> 不明瞭になってきています
# 釈徹宗は -> 不明瞭になってきています
# 哲学や -> 思想や -> 文学と -> 霊性論との -> 線引きも -> 不明瞭になってきています
# 思想や -> 文学と -> 霊性論との -> 線引きも -> 不明瞭になってきています
# 文学と -> 霊性論との -> 線引きも -> 不明瞭になってきています
# 宗教や -> 霊性論との -> 線引きも -> 不明瞭になってきています
# 霊性論との -> 線引きも -> 不明瞭になってきています
# 線引きも -> 不明瞭になってきています
# 不明瞭になってきています
# 哲学者倫理学者である -> 内田樹に -> よれば -> している
# 内田樹に -> よれば -> している
# 本物の -> 哲学者は -> している
# 哲学者は -> している
# みんな -> している
# 死者と -> 幽霊と -> 異界の -> 話を -> している
# 幽霊と -> 異界の -> 話を -> している
# 異界の -> 話を -> している
# 話を -> している
# 発明家レイカーツワイルが -> 言うには -> 話題である
# 哲学者ジョンサールが -> 提起した -> AIの -> 論争は -> 話題である
# 提起した -> AIの -> 論争は -> 話題である
# AIと -> 弱い -> AIの -> 論争は -> 話題である
# AIの -> 論争は -> 話題である
# 論争は -> 話題である
# AIの -> 哲学議論で -> 話題である
# 哲学議論で -> 話題である
# ホットな -> 話題である
# 話題である
# 哲学者ジョンサールおよび -> ダニエル・デネットに -> よると -> 主張している
# ダニエル・デネットに -> よると -> 主張している
# サールの -> 部屋や -> 中国脳といった -> 機能主義に -> 批判的な -> 思考実験は -> 主張している
# 中国語の -> 部屋や -> 中国脳といった -> 機能主義に -> 批判的な -> 思考実験は -> 主張している
# 部屋や -> 中国脳といった -> 機能主義に -> 批判的な -> 思考実験は -> 主張している
# ネドブロックらの -> 中国脳といった -> 機能主義に -> 批判的な -> 思考実験は -> 主張している
# 中国脳といった -> 機能主義に -> 批判的な -> 思考実験は -> 主張している
# 機能主義に -> 批判的な -> 思考実験は -> 主張している
# 批判的な -> 思考実験は -> 主張している
# 思考実験は -> 主張している
# 真の -> 意識が -> 実現できないと -> 主張している
# 意識が -> 実現できないと -> 主張している
# 形式論理システムによって -> 実現できないと -> 主張している
# 実現できないと -> 主張している
# 主張している
# 科学を -> 語るとは -> ことかにおいて -> 指摘している
# ことかにおいて -> 指摘している
# 科学者の -> 須藤靖は -> 指摘している
# 須藤靖は -> 指摘している
# 科学についての -> 哲学的考察 -> 科学哲学が -> 指摘している
# 哲学的考察 -> 科学哲学が -> 指摘している
# 科学哲学が -> 指摘している
# 科学と -> 断絶している -> ことを -> 指摘している
# 断絶している -> ことを -> 指摘している
# ことを -> 指摘している
# 指摘している
# 心や -> 意識という -> 問題を -> 解明してきた -> 脳科学計算機科学 -> コンピュータ科学人工知能研究開発等に -> 関連して -> 批判している
# 意識という -> 問題を -> 解明してきた -> 脳科学計算機科学 -> コンピュータ科学人工知能研究開発等に -> 関連して -> 批判している
# 問題を -> 解明してきた -> 脳科学計算機科学 -> コンピュータ科学人工知能研究開発等に -> 関連して -> 批判している
# 解明してきた -> 脳科学計算機科学 -> コンピュータ科学人工知能研究開発等に -> 関連して -> 批判している
# 脳科学計算機科学 -> コンピュータ科学人工知能研究開発等に -> 関連して -> 批判している
# コンピュータ科学人工知能研究開発等に -> 関連して -> 批判している
# 関連して -> 批判している
# 科学者の -> フランシスクリックは -> 批判している
# フランシスクリックは -> 批判している
# 哲学者たちは -> 2000年という -> 長い間 -> 残してこなかったと -> 批判している
# 2000年という -> 長い間 -> 残してこなかったと -> 批判している
# 長い間 -> 残してこなかったと -> 批判している
# 何も -> 残してこなかったと -> 批判している
# 成果を -> 残してこなかったと -> 批判している
# 批判している
# 観点において -> 評価されている
# 哲学は -> 過ぎないと -> 評価されている
# 二流どころか -> 三流の -> 学問科学に -> 過ぎないと -> 評価されている
# 三流の -> 学問科学に -> 過ぎないと -> 評価されている
# 学問科学に -> 過ぎないと -> 評価されている
# 評価されている
# 脳科学者の -> 澤口俊之は -> 述べている
# 澤口俊之は -> 述べている
# クリックに -> 賛同し -> 述べている
# 賛同し -> 述べている
# これは -> なるが -> 思うと -> 述べている
# 私の -> ため息まじりの -> 愚痴に -> なるが -> 思うと -> 述べている
# ため息まじりの -> 愚痴に -> なるが -> 思うと -> 述べている
# 愚痴に -> なるが -> 思うと -> 述べている
# 哲学者や -> 思想家というのは -> 思うと -> 述べている
# 思想家というのは -> 思うと -> 述べている
# 暇だと -> 思うと -> 述べている
# 哲学は -> 始まったと -> 伝えており -> 言う
# 暇 -> スコレーから -> 始まったと -> 伝えており -> 言う
# スコレーから -> 始まったと -> 伝えており -> 言う
# アリストテレスが -> 伝えており -> 言う
# 上記のような -> 否定的発言も -> 的外れではないと -> 言う
# 否定的発言も -> 的外れではないと -> 言う
# 的外れではないと -> 言う
# 科学哲学者の -> 野家啓一は -> 言う
# 野家啓一は -> 言う
# 哲学者は -> 語ろうとしてきた
# 科学とは -> 違う -> 日常的言語で -> 語ろうとしてきた
# 日常的言語で -> 語ろうとしてきた
# 存在や -> 宇宙を -> 語ろうとしてきた
# 宇宙を -> 語ろうとしてきた
# 理論物理学者ディラックは -> 信用していなかった
# 哲学者を -> 信用していなかった
# 信用していなかった
# ディラックが -> 見た -> ところ -> 理解していない
# ところ -> 理解していない
# ウィトゲンシュタインを -> 含め -> 量子力学どころか -> 理解していない
# 哲学者たちは -> 量子力学どころか -> 理解していない
# 量子力学どころか -> 理解していない
# パスカル以降の -> 確率の -> 概念さえ -> 理解していない
# 確率の -> 概念さえ -> 理解していない
# 概念さえ -> 理解していない
# 理解していない
# 非科学的な -> 日常的言語を -> 使っても -> できないというのが -> 考えだと -> されている
# 日常的言語を -> 使っても -> できないというのが -> 考えだと -> されている
# 正確な -> 意思疎通を -> 行う -> ことは -> できないというのが -> 考えだと -> されている
# 意思疎通を -> 行う -> ことは -> できないというのが -> 考えだと -> されている
# ことは -> できないというのが -> 考えだと -> されている
# できないというのが -> 考えだと -> されている
# ディラックの -> 考えだと -> されている
# 考えだと -> されている
# 生命情報科学者神経科学者の -> 合原一幸編著 -> 創られるに -> よれば -> 話ではない
# 合原一幸編著 -> 創られるに -> よれば -> 話ではない
# 人工知能は -> 創られるに -> よれば -> 話ではない
# AIの -> 発展に -> 伴って -> 論じられているが -> 話ではない
# 急激な -> 発展に -> 伴って -> 論じられているが -> 話ではない
# 発展に -> 伴って -> 論じられているが -> 話ではない
# 技術的特異点 -> シンギュラリティの -> 哲学が -> 論じられているが -> 話ではない
# シンギュラリティの -> 哲学が -> 論じられているが -> 話ではない
# 思想や -> 哲学が -> 論じられているが -> 話ではない
# 哲学が -> 論じられているが -> 話ではない
# 一部で -> 論じられているが -> 話ではない
# 特異点と -> 言っても -> 話ではない
# 数学的な -> 話ではない
# 話ではない
# 前掲書は -> 記している
# シンギュラリティと -> 関係した -> 議論における -> 超えるという -> 言明自体が -> 定義できていないと -> 記している
# 関係した -> 議論における -> 超えるという -> 言明自体が -> 定義できていないと -> 記している
# 議論における -> 超えるという -> 言明自体が -> 定義できていないと -> 記している
# 人間の -> 脳を -> 超えるという -> 言明自体が -> 定義できていないと -> 記している
# 脳を -> 超えるという -> 言明自体が -> 定義できていないと -> 記している
# 言明自体が -> 定義できていないと -> 記している
# 定義できていないと -> 記している
# 確かに -> 起こり得るかもしれない
# 脳を -> 捉える -> 観点から -> 見れば -> 起こり得るかもしれない
# デジタル情報処理システムとして -> 捉える -> 観点から -> 見れば -> 起こり得るかもしれない
# 観点から -> 見れば -> 起こり得るかもしれない
# シンギュラリティは -> 起こり得るかもしれない
# 脳は -> 示されている
# そのような -> システムではなく -> ハイブリッド系である -> ことが -> 示されている
# 単純な -> システムではなく -> ハイブリッド系である -> ことが -> 示されている
# システムではなく -> ハイブリッド系である -> ことが -> 示されている
# デジタルと -> アナログが -> 融合した -> ハイブリッド系である -> ことが -> 示されている
# アナログが -> 融合した -> ハイブリッド系である -> ことが -> 示されている
# 融合した -> ハイブリッド系である -> ことが -> 示されている
# ハイブリッド系である -> ことが -> 示されている
# ことが -> 示されている
# 脳神経科学の -> 観察結果で -> 示されている
# 観察結果で -> 示されている
# 前掲書に -> よると -> 考えられている
# 神経膜では -> 存在し -> 生み出されている -> ため -> 考えられている
# 様々な -> ノイズが -> 存在し -> 生み出されている -> ため -> 考えられている
# ノイズが -> 存在し -> 生み出されている -> ため -> 考えられている
# 存在し -> 生み出されている -> ため -> 考えられている
# ノイズ付きの -> アナログ量によって -> 生み出されている -> ため -> 考えられている
# アナログ量によって -> 生み出されている -> ため -> 考えられている
# 脳内の -> ニューロンの -> カオスが -> 生み出されている -> ため -> 考えられている
# ニューロンの -> カオスが -> 生み出されている -> ため -> 考えられている
# カオスが -> 生み出されている -> ため -> 考えられている
# ため -> 考えられている
# このような -> 状況を -> 記述する -> ことは -> 困難と -> 考えられている
# 状況を -> 記述する -> ことは -> 困難と -> 考えられている
# デジタルで -> 記述する -> ことは -> 困難と -> 考えられている
# 記述する -> ことは -> 困難と -> 考えられている
# ことは -> 困難と -> 考えられている
# 困難と -> 考えられている
# 数学者の -> 田中一之は -> 述べており -> 批判している
# 田中一之は -> 述べており -> 批判している
# 一般の -> 哲学者は -> 専門家ではないと -> 述べており -> 批判している
# 哲学者は -> 専門家ではないと -> 述べており -> 批判している
# 論理の -> 専門家ではないと -> 述べており -> 批判している
# 専門家ではないと -> 述べており -> 批判している
# 計算機科学者 -> コンピュータ科学者電子工学者の -> トルケルフランセーンは -> 批判している
# コンピュータ科学者電子工学者の -> トルケルフランセーンは -> 批判している
# トルケルフランセーンは -> 批判している
# 哲学者たちによる -> 言及の -> 多くが -> 批判している
# 数学的な -> 言及の -> 多くが -> 批判している
# 言及の -> 多くが -> 批判している
# 多くが -> 批判している
# 誤解や -> 自由連想に -> 基づいていると -> 批判している
# 自由連想に -> 基づいていると -> 批判している
# 批判している
# 田中に -> よると -> 酷評された
# ゲーデルの -> 不完全性定理について -> 書いた -> 本が -> 書店販売されていたが -> 酷評された
# 不完全性定理について -> 書いた -> 本が -> 書店販売されていたが -> 酷評された
# 哲学者が -> 書いた -> 本が -> 書店販売されていたが -> 酷評された
# 本が -> 書店販売されていたが -> 酷評された
# フランセーンの -> 本と -> 同じ -> 頃に -> 書店販売されていたが -> 酷評された
# 本と -> 同じ -> 頃に -> 書店販売されていたが -> 酷評された
# 頃に -> 書店販売されていたが -> 酷評された
# 書店販売されていたが -> 酷評された
# 哲学者の -> 本は -> 酷評された
# 本は -> 酷評された
# 専門誌によって -> 酷評された
# 酷評された
# 本は -> 高かったが -> 説明していた
# 全体として -> 高かったが -> 説明していた
# 一般読者からの -> 評判は -> 高かったが -> 説明していた
# 評判は -> 高かったが -> 説明していた
# ゲーデルの -> 証明の -> 核 -> 不動点定理について -> 説明していた
# 証明の -> 核 -> 不動点定理について -> 説明していた
# 核 -> 不動点定理について -> 説明していた
# 不動点定理について -> 説明していた
# 根本的な -> 勘違いを -> したまま -> 説明していた
# 勘違いを -> したまま -> 説明していた
# したまま -> 説明していた
# 説明していた
# 同様の -> 間違いは -> 見られる
# 間違いは -> 見られる
# 他の -> 入門書などにも -> 見られる
# 入門書などにも -> 見られる
# フランセーンに -> よれば -> 乱用されている
# 不完全性定理に関する -> 誤解誤用は -> 起こっており -> 乱用されている
# 誤解誤用は -> 起こっており -> 乱用されている
# 哲学を -> はじめ -> 起こっており -> 乱用されている
# はじめ -> 起こっており -> 乱用されている
# 一般に -> 起こっており -> 乱用されている
# 宗教や -> 神学でも -> 乱用されている
# 神学でも -> 乱用されている
# 乱用されている
# 1931年に -> 示したのは -> 定理ではない
# ゲーデルが -> 示したのは -> 定理ではない
# 示したのは -> 定理ではない
# 特定の -> 形式体系formula_1において -> 存在であり -> 定理ではない
# 形式体系formula_1において -> 存在であり -> 定理ではない
# 決定 -> 不能な -> 命題の -> 存在であり -> 定理ではない
# 不能な -> 命題の -> 存在であり -> 定理ではない
# 命題の -> 存在であり -> 定理ではない
# 存在であり -> 定理ではない
# 一般的な -> 意味での -> 不完全性についての -> 定理ではない
# 意味での -> 不完全性についての -> 定理ではない
# 不完全性についての -> 定理ではない
# 定理ではない
# 科学を -> 語るとは -> ことかに -> よると -> 研究するようになった
# ことかに -> よると -> 研究するようになった
# 学問の -> 扱う -> 問題が -> 整理され -> 分化した -> ことで -> 研究するようになった
# 問題が -> 整理され -> 分化した -> ことで -> 研究するようになった
# 整理され -> 分化した -> ことで -> 研究するようになった
# 分化した -> ことで -> 研究するようになった
# ことで -> 研究するようになった
# 科学と -> 哲学も -> 異なる -> 問題を -> 研究するようになった
# 哲学も -> 異なる -> 問題を -> 研究するようになった
# それぞれ -> 異なる -> 問題を -> 研究するようになった
# 問題を -> 研究するようになった
# 研究するようになった
# これは -> 言う
# 研究分野の -> 細分化そのものであり -> 言う
# 細分化そのものであり -> 言う
# 立派な -> 進歩だと -> 言う
# 進歩だと -> 言う
# 宇宙物理学者の -> 須藤は -> 言う
# 須藤は -> 言う
# 科学哲学者倫理学者の -> 伊勢田哲治は -> 言及した
# 伊勢田哲治は -> 言及した
# 様々な -> 要素を -> 含んだ -> 大きな問題を -> 扱う -> 天文学について -> 言及した
# 要素を -> 含んだ -> 大きな問題を -> 扱う -> 天文学について -> 言及した
# 大きな問題を -> 扱う -> 天文学について -> 言及した
# 哲学的統一的に -> 扱う -> 天文学について -> 言及した
# 天文学について -> 言及した
# 言及した
# その後の -> 天文学では -> 扱わなくなりましたし -> 扱わないと -> 述べた -> 伊勢田に対し -> 返している
# 天文学では -> 扱わなくなりましたし -> 扱わないと -> 述べた -> 伊勢田に対し -> 返している
# 哲学的問題を -> 扱わなくなりましたし -> 扱わないと -> 述べた -> 伊勢田に対し -> 返している
# 今の -> 物理学でも -> 扱わないと -> 述べた -> 伊勢田に対し -> 返している
# 物理学でも -> 扱わないと -> 述べた -> 伊勢田に対し -> 返している
# 問題を -> 扱わないと -> 述べた -> 伊勢田に対し -> 返している
# 伊勢田に対し -> 返している
# 須藤は -> 返している
# その通りですが -> あるのでしょうかと -> 返している
# それ自体に -> あるのでしょうかと -> 返している
# 何か -> あるのでしょうかと -> 返している
# 問題が -> あるのでしょうかと -> 返している
# あるのでしょうかと -> 返している
# 須藤は -> 述べた
# 次のようにも -> 述べた
# 須藤は -> している
# 哲学的に -> 論じられている -> 原因という -> 言葉を -> 取り上げて -> 述べており -> している
# 原因という -> 言葉を -> 取り上げて -> 述べており -> している
# 言葉を -> 取り上げて -> 述べており -> している
# 原因という -> 言葉を -> 定義しない -> 限り -> 不可能ですと -> 述べており -> している
# 言葉を -> 定義しない -> 限り -> 不可能ですと -> 述べており -> している
# 具体的に -> 定義しない -> 限り -> 不可能ですと -> 述べており -> している
# 定義しない -> 限り -> 不可能ですと -> 述べており -> している
# 限り -> 不可能ですと -> 述べており -> している
# それ以上の -> 議論は -> 不可能ですと -> 述べており -> している
# 議論は -> 不可能ですと -> 述べており -> している
# 不可能ですと -> 述べており -> している
# 哲学者が -> 持っている -> 因果の -> 定義が -> 違う -> ことは -> 確かでしょうと -> している
# 興味を -> 持っている -> 因果の -> 定義が -> 違う -> ことは -> 確かでしょうと -> している
# 因果の -> 定義が -> 違う -> ことは -> 確かでしょうと -> している
# 定義が -> 違う -> ことは -> 確かでしょうと -> している
# 物理学者とは -> 違う -> ことは -> 確かでしょうと -> している
# ことは -> 確かでしょうと -> している
# 確かでしょうと -> している
# 伊勢田は -> 述べている
# 以上に -> 違いというのは -> 大きいのかもしれませんと -> 述べている
# 物理学者と -> 哲学者の -> ものの -> 見え方の -> 違いというのは -> 大きいのかもしれませんと -> 述べている
# 哲学者の -> ものの -> 見え方の -> 違いというのは -> 大きいのかもしれませんと -> 述べている
# ものの -> 見え方の -> 違いというのは -> 大きいのかもしれませんと -> 述べている
# 見え方の -> 違いというのは -> 大きいのかもしれませんと -> 述べている
# 違いというのは -> 大きいのかもしれませんと -> 述べている
# 大きいのかもしれませんと -> 述べている
# 対談で -> 行ってきました
# 須藤は -> 行ってきました
# これまで -> 行ってきました
# 長時間 -> 行ってきました
# 議論を -> 行ってきました
# おかげで -> 明らかになったとは -> 思いますが -> つくのでしょうかと -> 発言し -> 答えている
# 意見の -> 違いは -> 明らかになったとは -> 思いますが -> つくのでしょうかと -> 発言し -> 答えている
# 違いは -> 明らかになったとは -> 思いますが -> つくのでしょうかと -> 発言し -> 答えている
# 明らかになったとは -> 思いますが -> つくのでしょうかと -> 発言し -> 答えている
# 何か -> つくのでしょうかと -> 発言し -> 答えている
# 決着が -> つくのでしょうかと -> 発言し -> 答えている
# つくのでしょうかと -> 発言し -> 答えている
# 発言し -> 答えている
# 伊勢田は -> 答えている
# 決着は -> つかないでしょうねと -> 答えている
